# %% [markdown]
# # Practical Work 3

# %% [markdown]
# ## Loading the packages

# %%
import numpy as np
import matplotlib.pyplot as pl ## hello

# %% [markdown]
# ## The Dataset

# %%
# %pip install ipympl
# Out:
# /home/yomaru/HEIG/arn/ARN-PW3/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

 # Change this to any folder where data is if needed
mouse1 = pd.read_csv('EEG_mouse_data_1.csv')
mouse2 = pd.read_csv('EEG_mouse_data_2.csv')
dataset = pd.concat([mouse1, mouse2])
test_data = pd.read_csv('EEG_mouse_data_test.csv')
dataset
# Out:
#       state  amplitude_around_1_Hertz  amplitude_around_2_Hertz  \
# 0         n                  0.000009                  0.000014
# 1         n                  0.000010                  0.000010
# 2         n                  0.000011                  0.000077
# 3         w                  0.000003                  0.000031
# 4         w                  0.000010                  0.000011
# ...     ...                       ...                       ...
# 20600     w                  0.000025                  0.000007
# 20601     w                  0.000017                  0.000038
# 20602     w                  0.000016                  0.000028
# 20603     w                  0.000013                  0.000014
# 20604     w                  0.000004                  0.000006
#
#        amplitude_around_3_Hertz  amplitude_around_4_Hertz  \
# 0                      0.000013                  0.000014
# 1                      0.000011                  0.000015
# 2                      0.000034                  0.000019
# 3                      0.000044                  0.000016
# 4                      0.000012                  0.000017
# ...                         ...                       ...
# 20600                  0.000007                  0.000003
# 20601                  0.000015                  0.000011
# 20602                  0.000031                  0.000011
# 20603                  0.000020                  0.000018
# 20604                  0.000011                  0.000025
#
#        amplitude_around_5_Hertz  amplitude_around_6_Hertz  \
# 0                      0.000023                  0.000009
# 1                      0.000022                  0.000017
# 2                      0.000013                  0.000006
# 3                      0.000007                  0.000006
# 4                      0.000020                  0.000018
# ...                         ...                       ...
# 20600                  0.000005                  0.000002
# 20601                  0.000019                  0.000006
# 20602                  0.000019                  0.000001
# 20603                  0.000007                  0.000013
# 20604                  0.000040                  0.000007
#
#        amplitude_around_7_Hertz  amplitude_around_8_Hertz  \
# 0                      0.000019                  0.000011
# 1                      0.000027                  0.000011
# 2                      0.000010                  0.000004
# 3                      0.000005                  0.000007
# 4                      0.000014                  0.000025
# ...                         ...                       ...
# 20600                  0.000005                  0.000010
# 20601                  0.000010                  0.000012
# 20602                  0.000015                  0.000002
# 20603                  0.000009                  0.000018
# 20604                  0.000005                  0.000021
#
#        amplitude_around_9_Hertz  ...  amplitude_around_92_Hertz  \
# 0                      0.000016  ...               8.364060e-09
# 1                      0.000011  ...               6.695745e-09
# 2                      0.000006  ...               1.105705e-08
# 3                      0.000006  ...               2.223992e-08
# 4                      0.000018  ...               6.541705e-09
# ...                         ...  ...                        ...
# 20600                  0.000013  ...               1.162051e-08
# 20601                  0.000009  ...               1.456810e-08
# 20602                  0.000007  ...               1.197483e-08
# 20603                  0.000005  ...               3.028127e-08
# 20604                  0.000011  ...               1.434414e-08
#
#        amplitude_around_93_Hertz  amplitude_around_94_Hertz  \
# 0                   4.208368e-09               2.177679e-09
# 1                   1.213822e-08               2.287185e-08
# 2                   3.264479e-09               1.204057e-09
# 3                   1.028462e-08               3.561479e-09
# 4                   3.312024e-09               8.779863e-09
# ...                          ...                        ...
# 20600               9.470367e-09               1.542617e-08
# 20601               9.259630e-09               3.831858e-08
# 20602               2.496412e-08               2.292325e-08
# 20603               9.760537e-09               3.475243e-09
# 20604               1.081698e-08               6.120670e-09
#
#        amplitude_around_95_Hertz  amplitude_around_96_Hertz  \
# 0                   4.342505e-09               5.130010e-09
# 1                   3.219380e-09               2.461736e-09
# 2                   5.090074e-09               5.477467e-09
# 3                   3.704753e-09               2.425319e-09
# 4                   7.400000e-09               2.890853e-09
# ...                          ...                        ...
# 20600               6.114029e-09               2.346950e-09
# 20601               3.839020e-09               4.668449e-09
# 20602               2.783310e-09               6.423075e-09
# 20603               2.667755e-09               4.243288e-09
# 20604               4.113743e-09               6.910015e-09
#
#        amplitude_around_97_Hertz  amplitude_around_98_Hertz  \
# 0                   2.852361e-09               9.772395e-10
# 1                   2.985953e-09               1.434412e-09
# 2                   1.809223e-09               7.064289e-10
# 3                   1.536834e-09               2.540238e-10
# 4                   5.709757e-10               2.171227e-09
# ...                          ...                        ...
# 20600               4.264138e-09               1.733832e-09
# 20601               1.671207e-09               2.347928e-09
# 20602               3.649511e-09               4.350072e-09
# 20603               6.048632e-09               3.234623e-09
# 20604               7.412423e-09               3.527602e-09
#
#        amplitude_around_99_Hertz  amplitude_around_100_Hertz  \
# 0                   1.876307e-09                5.457793e-09
# 1                   1.579590e-09                5.458902e-09
# 2                   1.435585e-09                7.416121e-09
# 3                   6.300358e-10                3.647454e-09
# 4                   6.757242e-10                2.005702e-09
# ...                          ...                         ...
# 20600               8.314190e-10                1.720087e-09
# 20601               2.219437e-09                2.045267e-09
# 20602               6.656486e-10                2.086456e-09
# 20603               1.421633e-09                9.709723e-10
# 20604               2.895608e-09                4.211010e-09
#
#        amplitude_around_101_Hertz
# 0                    8.653900e-08
# 1                    8.492570e-08
# 2                    1.156240e-07
# 3                    2.212800e-08
# 4                    2.861980e-10
# ...                           ...
# 20600                1.345590e-09
# 20601                6.063210e-09
# 20602                2.761580e-08
# 20603                2.062290e-08
# 20604                3.054510e-08
#
# [40863 rows x 102 columns]

# %% [markdown]
# <font color="red">**For it to work on Colab, you will need to reload your session (Exécution -> redémarrer la session)**</font>

# %% [markdown]
# <font color="orange">**Make sure to put a large amount of points otherwise the cross validation folds will be really small**</font>

# %% [markdown]
# ## Show the dataset

# %%
dataset = np.array(dataset)
test_data = np.array(test_data)
dataset
# Out:
# array([['n', 9.123150377376987e-06, 1.3656147984875132e-05, ...,
#         1.8763067211047253e-09, 5.457792863483579e-09,
#         8.653900351873746e-08],
#        ['n', 9.79506089393567e-06, 9.573940179308238e-06, ...,
#         1.5795897784220971e-09, 5.4589015668904395e-09,
#         8.492570202633942e-08],
#        ['n', 1.0809589923610474e-05, 7.670862305531045e-05, ...,
#         1.435585247899773e-09, 7.4161209742684706e-09,
#         1.1562399748754617e-07],
#        ...,
#        ['w', 1.6213877302106994e-05, 2.8464069458777885e-05, ...,
#         6.656486386397154e-10, 2.08645636011473e-09,
#         2.7615799425007026e-08],
#        ['w', 1.2860698049621533e-05, 1.3600040119854384e-05, ...,
#         1.421632783715765e-09, 9.70972280009419e-10,
#         2.062290072046835e-08],
#        ['w', 3.5420524397977715e-06, 5.874647627024388e-06, ...,
#         2.8956081976616584e-09, 4.211009985155556e-09,
#         3.054509889466317e-08]], shape=(40863, 102), dtype=object)

# %%
input_data = dataset[:, 1:11].astype(float)
feature_mean = input_data.mean(axis=0)
feature_std = input_data.std(axis=0) + 1e-8
input_data = (input_data - feature_mean) / feature_std  # Standardize each feature

state_to_class = {"w": 0, "r": 1, "n": 2}
output_data = np.array([state_to_class[state] for state in dataset[:, 0]], dtype=int)

temporal_window = 4

def make_past_context_features(X, window=4):
    # Builds [x(t-window), ..., x(t-1), x(t)] for each sample at time t
    n, d = X.shape
    context_parts = []
    for lag in range(window, 0, -1):
        shifted = np.empty_like(X)
        shifted[:lag] = X[0]
        shifted[lag:] = X[:-lag]
        context_parts.append(shifted)
    context_parts.append(X)
    return np.hstack(context_parts)

model_input_data = make_past_context_features(input_data, window=temporal_window)

# test_data has only features (no state column in EEG_mouse_data_test.csv)
test_input_data = test_data[:, :10].astype(float)
test_input_data = (test_input_data - feature_mean) / feature_std
test_model_input_data = make_past_context_features(test_input_data, window=temporal_window)

val_input = test_model_input_data
val_output = None

# %%
input_data
# Out:
# array([[-0.20987265, -0.08194901, -0.1050478 , ..., -0.12720215,
#          0.70849675,  1.30767881],
#        [-0.1833618 , -0.32559618, -0.23035843, ..., -0.1001689 ,
#          0.09924395,  0.25545035],
#        [-0.14333261,  3.68134731,  1.38922012, ..., -0.7483781 ,
#         -0.45690898, -0.72108948],
#        ...,
#        [ 0.06989857,  0.80186398,  1.18418179, ..., -0.92162007,
#         -0.29742897, -0.90504528],
#        [-0.06240423, -0.08529781,  0.37567232, ...,  0.54767347,
#         -0.59646021, -0.69274525],
#        [-0.43008006, -0.54638901, -0.24674486, ...,  0.81216587,
#          0.09678055,  0.04914934]], shape=(40863, 10))

# %%
output_data
# Out:
# array([2, 2, 2, ..., 0, 0, 0], shape=(40863,))

# %%
# Check data balance
class_names = ["Awake", "REM", "Non-REM"]
unique, counts = np.unique(output_data, return_counts=True)
for label, count in zip(unique, counts):
    state = class_names[label]
    print(f"{state}: {count} samples ({count/len(output_data)*100:.1f}%)")
# Out:
# Awake: 24360 samples (59.6%)
# REM: 2839 samples (6.9%)
# Non-REM: 13664 samples (33.4%)

# %%
# %matplotlib inline

# %%
import keras
from keras import layers

pl.clf()

keras.utils.set_random_seed(123)

class_colors = {0: "tab:blue", 1: "tab:orange", 2: "tab:green"}
validation_color = "lightgray"
class_names = ["Awake", "REM", "Non-REM"]

pl.figure(figsize=(4,4))

# Plot train data and validation data
pl.scatter(input_data[:,0], input_data[:,1], c=[class_colors[int(d)] for d in output_data], s=100)
#pl.scatter(val_input[:,0], val_input[:,1], c=validation_color, s=100)
pl.title('Training data (colored)')
pl.show()

# %%
MODEL_CONFIG = {
  "input_dim": 50,
  "hidden_units": [32],
  "learning_rate": 5e-4,
  "batch_size": 128,
  "epochs": 300,
  "early_stopping_patience": 15,
  "reduce_lr_patience": 5,
  "reduce_lr_factor": 0.5,
  "min_lr": 1e-5,
}

def create_model(config=MODEL_CONFIG):
  # Keep this config aligned with the folds notebook
  mlp = keras.Sequential()
  mlp.add(layers.Input(shape=(config["input_dim"],)))

  for units in config["hidden_units"]:
      mlp.add(layers.Dense(units, activation="relu"))

  mlp.add(layers.Dense(3, activation="softmax"))

  mlp.compile(
      optimizer=keras.optimizers.Adam(learning_rate=config["learning_rate"]),
      loss="sparse_categorical_crossentropy",
      metrics=["accuracy"],
  )

  return mlp

mlp = create_model()
print("MODEL_CONFIG:", MODEL_CONFIG)
mlp.summary()
# Out:
# MODEL_CONFIG: {'input_dim': 50, 'hidden_units': [32], 'learning_rate': 0.0005, 'batch_size': 128, 'epochs': 300, 'early_stopping_patience': 15, 'reduce_lr_patience': 5, 'reduce_lr_factor': 0.5, 'min_lr': 1e-05}
# E0000 00:00:1775075123.329009   23884 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1775075123.342732   23884 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │         1,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,731 (6.76 KB)
#  Trainable params: 1,731 (6.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

monitor_metric = "val_loss" if val_output is not None else "loss"

early_stopping = EarlyStopping(
    monitor=monitor_metric,
    patience=MODEL_CONFIG["early_stopping_patience"],
    min_delta=1e-4,
    restore_best_weights=True,
)
reduce_lr = ReduceLROnPlateau(
    monitor=monitor_metric,
    factor=MODEL_CONFIG["reduce_lr_factor"],
    patience=MODEL_CONFIG["reduce_lr_patience"],
    min_delta=1e-4,
    min_lr=MODEL_CONFIG["min_lr"],
    verbose=1,
)

mlp = create_model()

class_values = np.unique(output_data)
class_weights = compute_class_weight(class_weight="balanced", classes=class_values, y=output_data)
class_weights = np.sqrt(class_weights)
class_weights = class_weights / np.mean(class_weights)
class_weight_dict = dict(zip(class_values, class_weights))

fit_kwargs = dict(
    x=model_input_data,
    y=output_data,
    epochs=MODEL_CONFIG["epochs"],
    batch_size=MODEL_CONFIG["batch_size"],
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr],
)

if val_output is not None:
    fit_kwargs["validation_data"] = (val_input, val_output)

history = mlp.fit(**fit_kwargs)
# Out:
# Epoch 1/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7740 - loss: 0.4535 - learning_rate: 5.0000e-04
# Epoch 2/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8735 - loss: 0.2805 - learning_rate: 5.0000e-04
# Epoch 3/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8835 - loss: 0.2528 - learning_rate: 5.0000e-04
# Epoch 4/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8885 - loss: 0.2404 - learning_rate: 5.0000e-04
# Epoch 5/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8913 - loss: 0.2326 - learning_rate: 5.0000e-04
# Epoch 6/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8940 - loss: 0.2266 - learning_rate: 5.0000e-04
# Epoch 7/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8953 - loss: 0.2217 - learning_rate: 5.0000e-04
# Epoch 8/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8978 - loss: 0.2175 - learning_rate: 5.0000e-04
# Epoch 9/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8997 - loss: 0.2139 - learning_rate: 5.0000e-04
# Epoch 10/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9013 - loss: 0.2109 - learning_rate: 5.0000e-04
# Epoch 11/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9024 - loss: 0.2082 - learning_rate: 5.0000e-04
# Epoch 12/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9033 - loss: 0.2058 - learning_rate: 5.0000e-04
# Epoch 13/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9045 - loss: 0.2037 - learning_rate: 5.0000e-04
# Epoch 14/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9050 - loss: 0.2018 - learning_rate: 5.0000e-04
# Epoch 15/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9056 - loss: 0.2002 - learning_rate: 5.0000e-04
# Epoch 16/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9068 - loss: 0.1986 - learning_rate: 5.0000e-04
# Epoch 17/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9075 - loss: 0.1972 - learning_rate: 5.0000e-04
# Epoch 18/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9081 - loss: 0.1960 - learning_rate: 5.0000e-04
# Epoch 19/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9087 - loss: 0.1948 - learning_rate: 5.0000e-04
# Epoch 20/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9092 - loss: 0.1936 - learning_rate: 5.0000e-04
# Epoch 21/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9096 - loss: 0.1926 - learning_rate: 5.0000e-04
# Epoch 22/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9099 - loss: 0.1916 - learning_rate: 5.0000e-04
# Epoch 23/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9102 - loss: 0.1907 - learning_rate: 5.0000e-04
# Epoch 24/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9104 - loss: 0.1898 - learning_rate: 5.0000e-04
# Epoch 25/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9108 - loss: 0.1890 - learning_rate: 5.0000e-04
# Epoch 26/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9109 - loss: 0.1882 - learning_rate: 5.0000e-04
# Epoch 27/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9112 - loss: 0.1875 - learning_rate: 5.0000e-04
# Epoch 28/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9112 - loss: 0.1868 - learning_rate: 5.0000e-04
# Epoch 29/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9115 - loss: 0.1862 - learning_rate: 5.0000e-04
# Epoch 30/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9115 - loss: 0.1855 - learning_rate: 5.0000e-04
# Epoch 31/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9119 - loss: 0.1849 - learning_rate: 5.0000e-04
# Epoch 32/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9121 - loss: 0.1843 - learning_rate: 5.0000e-04
# Epoch 33/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9124 - loss: 0.1838 - learning_rate: 5.0000e-04
# Epoch 34/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9126 - loss: 0.1833 - learning_rate: 5.0000e-04
# Epoch 35/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9130 - loss: 0.1828 - learning_rate: 5.0000e-04
# Epoch 36/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9131 - loss: 0.1823 - learning_rate: 5.0000e-04
# Epoch 37/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9132 - loss: 0.1818 - learning_rate: 5.0000e-04
# Epoch 38/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9133 - loss: 0.1813 - learning_rate: 5.0000e-04
# Epoch 39/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9136 - loss: 0.1809 - learning_rate: 5.0000e-04
# Epoch 40/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9140 - loss: 0.1804 - learning_rate: 5.0000e-04
# Epoch 41/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9143 - loss: 0.1800 - learning_rate: 5.0000e-04
# Epoch 42/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9145 - loss: 0.1796 - learning_rate: 5.0000e-04
# Epoch 43/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9145 - loss: 0.1792 - learning_rate: 5.0000e-04
# Epoch 44/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9148 - loss: 0.1788 - learning_rate: 5.0000e-04
# Epoch 45/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9150 - loss: 0.1784 - learning_rate: 5.0000e-04
# Epoch 46/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9151 - loss: 0.1781 - learning_rate: 5.0000e-04
# Epoch 47/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9155 - loss: 0.1778 - learning_rate: 5.0000e-04
# Epoch 48/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9158 - loss: 0.1774 - learning_rate: 5.0000e-04
# Epoch 49/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9161 - loss: 0.1771 - learning_rate: 5.0000e-04
# Epoch 50/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9160 - loss: 0.1768 - learning_rate: 5.0000e-04
# Epoch 51/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9162 - loss: 0.1765 - learning_rate: 5.0000e-04
# Epoch 52/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9164 - loss: 0.1762 - learning_rate: 5.0000e-04
# Epoch 53/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9165 - loss: 0.1759 - learning_rate: 5.0000e-04
# Epoch 54/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9168 - loss: 0.1756 - learning_rate: 5.0000e-04
# Epoch 55/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9168 - loss: 0.1753 - learning_rate: 5.0000e-04
# Epoch 56/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9169 - loss: 0.1750 - learning_rate: 5.0000e-04
# Epoch 57/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9169 - loss: 0.1748 - learning_rate: 5.0000e-04
# Epoch 58/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9171 - loss: 0.1745 - learning_rate: 5.0000e-04
# Epoch 59/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9172 - loss: 0.1742 - learning_rate: 5.0000e-04
# Epoch 60/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9172 - loss: 0.1740 - learning_rate: 5.0000e-04
# Epoch 61/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9175 - loss: 0.1738 - learning_rate: 5.0000e-04
# Epoch 62/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9175 - loss: 0.1735 - learning_rate: 5.0000e-04
# Epoch 63/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9176 - loss: 0.1733 - learning_rate: 5.0000e-04
# Epoch 64/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9176 - loss: 0.1731 - learning_rate: 5.0000e-04
# Epoch 65/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9177 - loss: 0.1728 - learning_rate: 5.0000e-04
# Epoch 66/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9179 - loss: 0.1726 - learning_rate: 5.0000e-04
# Epoch 67/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9178 - loss: 0.1724 - learning_rate: 5.0000e-04
# Epoch 68/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9178 - loss: 0.1722 - learning_rate: 5.0000e-04
# Epoch 69/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9177 - loss: 0.1720 - learning_rate: 5.0000e-04
# Epoch 70/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9178 - loss: 0.1718 - learning_rate: 5.0000e-04
# Epoch 71/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9179 - loss: 0.1716 - learning_rate: 5.0000e-04
# Epoch 72/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9180 - loss: 0.1714 - learning_rate: 5.0000e-04
# Epoch 73/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9179 - loss: 0.1712 - learning_rate: 5.0000e-04
# Epoch 74/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9180 - loss: 0.1710 - learning_rate: 5.0000e-04
# Epoch 75/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9183 - loss: 0.1708 - learning_rate: 5.0000e-04
# Epoch 76/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9184 - loss: 0.1706 - learning_rate: 5.0000e-04
# Epoch 77/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9183 - loss: 0.1705 - learning_rate: 5.0000e-04
# Epoch 78/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9185 - loss: 0.1703 - learning_rate: 5.0000e-04
# Epoch 79/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9186 - loss: 0.1701 - learning_rate: 5.0000e-04
# Epoch 80/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9188 - loss: 0.1699 - learning_rate: 5.0000e-04
# Epoch 81/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9188 - loss: 0.1697 - learning_rate: 5.0000e-04
# Epoch 82/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9187 - loss: 0.1696 - learning_rate: 5.0000e-04
# Epoch 83/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9190 - loss: 0.1694 - learning_rate: 5.0000e-04
# Epoch 84/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9191 - loss: 0.1692 - learning_rate: 5.0000e-04
# Epoch 85/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9191 - loss: 0.1690 - learning_rate: 5.0000e-04
# Epoch 86/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9193 - loss: 0.1689 - learning_rate: 5.0000e-04
# Epoch 87/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9192 - loss: 0.1687 - learning_rate: 5.0000e-04
# Epoch 88/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9193 - loss: 0.1685 - learning_rate: 5.0000e-04
# Epoch 89/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9195 - loss: 0.1684 - learning_rate: 5.0000e-04
# Epoch 90/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9195 - loss: 0.1682 - learning_rate: 5.0000e-04
# Epoch 91/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9195 - loss: 0.1681 - learning_rate: 5.0000e-04
# Epoch 92/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9197 - loss: 0.1679 - learning_rate: 5.0000e-04
# Epoch 93/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9198 - loss: 0.1678 - learning_rate: 5.0000e-04
# Epoch 94/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9198 - loss: 0.1676 - learning_rate: 5.0000e-04
# Epoch 95/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9199 - loss: 0.1675 - learning_rate: 5.0000e-04
# Epoch 96/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9199 - loss: 0.1673 - learning_rate: 5.0000e-04
# Epoch 97/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9201 - loss: 0.1672 - learning_rate: 5.0000e-04
# Epoch 98/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9200 - loss: 0.1671 - learning_rate: 5.0000e-04
# Epoch 99/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9199 - loss: 0.1669 - learning_rate: 5.0000e-04
# Epoch 100/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9200 - loss: 0.1668 - learning_rate: 5.0000e-04
# Epoch 101/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9200 - loss: 0.1667 - learning_rate: 5.0000e-04
# Epoch 102/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9199 - loss: 0.1665 - learning_rate: 5.0000e-04
# Epoch 103/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9199 - loss: 0.1664 - learning_rate: 5.0000e-04
# Epoch 104/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9201 - loss: 0.1663 - learning_rate: 5.0000e-04
# Epoch 105/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9199 - loss: 0.1662 - learning_rate: 5.0000e-04
# Epoch 106/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9201 - loss: 0.1661 - learning_rate: 5.0000e-04
# Epoch 107/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9202 - loss: 0.1660 - learning_rate: 5.0000e-04
# Epoch 108/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9201 - loss: 0.1658 - learning_rate: 5.0000e-04
# Epoch 109/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9201 - loss: 0.1657 - learning_rate: 5.0000e-04
# Epoch 110/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9202 - loss: 0.1656 - learning_rate: 5.0000e-04
# Epoch 111/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9202 - loss: 0.1655 - learning_rate: 5.0000e-04
# Epoch 112/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9203 - loss: 0.1654 - learning_rate: 5.0000e-04
# Epoch 113/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9203 - loss: 0.1653 - learning_rate: 5.0000e-04
# Epoch 114/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9207 - loss: 0.1652 - learning_rate: 5.0000e-04
# Epoch 115/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9204 - loss: 0.1651 - learning_rate: 5.0000e-04
# Epoch 116/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9206 - loss: 0.1650 - learning_rate: 5.0000e-04
# Epoch 117/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9205 - loss: 0.1649 - learning_rate: 5.0000e-04
# Epoch 118/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9208 - loss: 0.1648 - learning_rate: 5.0000e-04
# Epoch 119/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9207 - loss: 0.1647 - learning_rate: 5.0000e-04
# Epoch 120/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9207 - loss: 0.1646 - learning_rate: 5.0000e-04
# Epoch 121/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9208 - loss: 0.1645 - learning_rate: 5.0000e-04
# Epoch 122/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9208 - loss: 0.1645 - learning_rate: 5.0000e-04
# Epoch 123/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9211 - loss: 0.1644 - learning_rate: 5.0000e-04
# Epoch 124/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9211 - loss: 0.1643 - learning_rate: 5.0000e-04
# Epoch 125/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9212 - loss: 0.1642 - learning_rate: 5.0000e-04
# Epoch 126/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9212 - loss: 0.1641 - learning_rate: 5.0000e-04
# Epoch 127/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9211 - loss: 0.1640 - learning_rate: 5.0000e-04
# Epoch 128/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9212 - loss: 0.1640 - learning_rate: 5.0000e-04
# Epoch 129/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9212 - loss: 0.1639 - learning_rate: 5.0000e-04
# Epoch 130/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9210 - loss: 0.1638 - learning_rate: 5.0000e-04
# Epoch 131/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9210 - loss: 0.1637 - learning_rate: 5.0000e-04
# Epoch 132/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9210 - loss: 0.1637 - learning_rate: 5.0000e-04
# Epoch 133/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9210 - loss: 0.1636 - learning_rate: 5.0000e-04
# Epoch 134/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9210 - loss: 0.1636 - learning_rate: 5.0000e-04
# Epoch 135/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9210 - loss: 0.1634 - learning_rate: 5.0000e-04
# Epoch 136/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9210 - loss: 0.1634 - learning_rate: 5.0000e-04
# Epoch 137/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9212 - loss: 0.1633 - learning_rate: 5.0000e-04
# Epoch 138/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9211 - loss: 0.1632 - learning_rate: 5.0000e-04
# Epoch 139/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9214 - loss: 0.1631 - learning_rate: 5.0000e-04
# Epoch 140/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9214 - loss: 0.1631 - learning_rate: 5.0000e-04
# Epoch 141/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9214 - loss: 0.1630 - learning_rate: 5.0000e-04
# Epoch 142/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9217 - loss: 0.1629 - learning_rate: 5.0000e-04
# Epoch 143/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9217 - loss: 0.1628 - learning_rate: 5.0000e-04
# Epoch 144/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9219 - loss: 0.1627 - learning_rate: 5.0000e-04
# Epoch 145/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9219 - loss: 0.1627 - learning_rate: 5.0000e-04
# Epoch 146/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9219 - loss: 0.1626 - learning_rate: 5.0000e-04
# Epoch 147/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9218 - loss: 0.1625 - learning_rate: 5.0000e-04
# Epoch 148/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9219 - loss: 0.1624 - learning_rate: 5.0000e-04
# Epoch 149/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9218 - loss: 0.1624 - learning_rate: 5.0000e-04
# Epoch 150/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9218 - loss: 0.1623 - learning_rate: 5.0000e-04
# Epoch 151/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9218 - loss: 0.1622 - learning_rate: 5.0000e-04
# Epoch 152/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9218 - loss: 0.1622 - learning_rate: 5.0000e-04
# Epoch 153/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9220 - loss: 0.1621 - learning_rate: 5.0000e-04
# Epoch 154/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9218 - loss: 0.1620 - learning_rate: 5.0000e-04
# Epoch 155/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9219 - loss: 0.1619 - learning_rate: 5.0000e-04
# Epoch 156/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9219 - loss: 0.1619 - learning_rate: 5.0000e-04
# Epoch 157/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9219 - loss: 0.1618 - learning_rate: 5.0000e-04
# Epoch 158/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9220 - loss: 0.1618 - learning_rate: 5.0000e-04
# Epoch 159/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9220 - loss: 0.1617 - learning_rate: 5.0000e-04
# Epoch 160/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9221 - loss: 0.1616 - learning_rate: 5.0000e-04
# Epoch 161/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9222 - loss: 0.1616 - learning_rate: 5.0000e-04
# Epoch 162/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9221 - loss: 0.1615 - learning_rate: 5.0000e-04
# Epoch 163/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9223 - loss: 0.1615 - learning_rate: 5.0000e-04
# Epoch 164/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9221 - loss: 0.1614 - learning_rate: 5.0000e-04
# Epoch 165/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9222 - loss: 0.1613 - learning_rate: 5.0000e-04
# Epoch 166/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9221 - loss: 0.1613 - learning_rate: 5.0000e-04
# Epoch 167/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9222 - loss: 0.1612 - learning_rate: 5.0000e-04
# Epoch 168/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9222 - loss: 0.1612 - learning_rate: 5.0000e-04
# Epoch 169/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9224 - loss: 0.1611 - learning_rate: 5.0000e-04
# Epoch 170/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9224 - loss: 0.1610 - learning_rate: 5.0000e-04
# Epoch 171/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9225 - loss: 0.1610 - learning_rate: 5.0000e-04
# Epoch 172/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9225 - loss: 0.1609 - learning_rate: 5.0000e-04
# Epoch 173/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9225 - loss: 0.1608 - learning_rate: 5.0000e-04
# Epoch 174/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9225 - loss: 0.1608 - learning_rate: 5.0000e-04
# Epoch 175/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9224 - loss: 0.1607 - learning_rate: 5.0000e-04
# Epoch 176/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9224 - loss: 0.1607 - learning_rate: 5.0000e-04
# Epoch 177/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9224 - loss: 0.1607 - learning_rate: 5.0000e-04
# Epoch 178/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9227 - loss: 0.1606 - learning_rate: 5.0000e-04
# Epoch 179/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9225 - loss: 0.1606 - learning_rate: 5.0000e-04
# Epoch 180/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9226 - loss: 0.1605 - learning_rate: 5.0000e-04
# Epoch 181/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9227 - loss: 0.1605 - learning_rate: 5.0000e-04
# Epoch 182/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9227 - loss: 0.1604 - learning_rate: 5.0000e-04
# Epoch 183/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9229 - loss: 0.1603 - learning_rate: 5.0000e-04
# Epoch 184/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9229 - loss: 0.1603 - learning_rate: 5.0000e-04
# Epoch 185/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9229 - loss: 0.1602 - learning_rate: 5.0000e-04
# Epoch 186/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9229 - loss: 0.1601 - learning_rate: 5.0000e-04
# Epoch 187/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9227 - loss: 0.1601 - learning_rate: 5.0000e-04
# Epoch 188/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9229 - loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 189/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9229 - loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 190/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9229 - loss: 0.1599 - learning_rate: 5.0000e-04
# Epoch 191/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9229 - loss: 0.1599 - learning_rate: 5.0000e-04
# Epoch 192/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9229 - loss: 0.1598 - learning_rate: 5.0000e-04
# Epoch 193/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9231 - loss: 0.1598 - learning_rate: 5.0000e-04
# Epoch 194/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9230 - loss: 0.1597 - learning_rate: 5.0000e-04
# Epoch 195/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9230 - loss: 0.1597 - learning_rate: 5.0000e-04
# Epoch 196/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9230 - loss: 0.1597 - learning_rate: 5.0000e-04
# Epoch 197/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9229 - loss: 0.1596 - learning_rate: 5.0000e-04
# Epoch 198/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9230 - loss: 0.1596 - learning_rate: 5.0000e-04
# Epoch 199/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9229 - loss: 0.1596 - learning_rate: 5.0000e-04
# Epoch 200/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9228 - loss: 0.1596 - learning_rate: 5.0000e-04
# Epoch 201/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9228 - loss: 0.1596 - learning_rate: 5.0000e-04
# Epoch 202/300
# 301/320 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9214 - loss: 0.1599
# Epoch 202: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9228 - loss: 0.1596 - learning_rate: 5.0000e-04
# Epoch 203/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9236 - loss: 0.1579 - learning_rate: 2.5000e-04
# Epoch 204/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9235 - loss: 0.1578 - learning_rate: 2.5000e-04
# Epoch 205/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9234 - loss: 0.1577 - learning_rate: 2.5000e-04
# Epoch 206/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9235 - loss: 0.1577 - learning_rate: 2.5000e-04
# Epoch 207/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9235 - loss: 0.1576 - learning_rate: 2.5000e-04
# Epoch 208/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9236 - loss: 0.1576 - learning_rate: 2.5000e-04
# Epoch 209/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9237 - loss: 0.1576 - learning_rate: 2.5000e-04
# Epoch 210/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9238 - loss: 0.1575 - learning_rate: 2.5000e-04
# Epoch 211/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9239 - loss: 0.1575 - learning_rate: 2.5000e-04
# Epoch 212/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9240 - loss: 0.1575 - learning_rate: 2.5000e-04
# Epoch 213/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9240 - loss: 0.1575 - learning_rate: 2.5000e-04
# Epoch 214/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1574 - learning_rate: 2.5000e-04
# Epoch 215/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1574 - learning_rate: 2.5000e-04
# Epoch 216/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1574 - learning_rate: 2.5000e-04
# Epoch 217/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9239 - loss: 0.1574 - learning_rate: 2.5000e-04
# Epoch 218/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9239 - loss: 0.1573 - learning_rate: 2.5000e-04
# Epoch 219/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9238 - loss: 0.1573 - learning_rate: 2.5000e-04
# Epoch 220/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9238 - loss: 0.1573 - learning_rate: 2.5000e-04
# Epoch 221/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9239 - loss: 0.1572 - learning_rate: 2.5000e-04
# Epoch 222/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9238 - loss: 0.1572 - learning_rate: 2.5000e-04
# Epoch 223/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9238 - loss: 0.1572 - learning_rate: 2.5000e-04
# Epoch 224/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9240 - loss: 0.1572 - learning_rate: 2.5000e-04
# Epoch 225/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9239 - loss: 0.1572 - learning_rate: 2.5000e-04
# Epoch 226/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9240 - loss: 0.1571 - learning_rate: 2.5000e-04
# Epoch 227/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9240 - loss: 0.1571 - learning_rate: 2.5000e-04
# Epoch 228/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1571 - learning_rate: 2.5000e-04
# Epoch 229/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1571 - learning_rate: 2.5000e-04
# Epoch 230/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9242 - loss: 0.1570 - learning_rate: 2.5000e-04
# Epoch 231/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9242 - loss: 0.1570 - learning_rate: 2.5000e-04
# Epoch 232/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9242 - loss: 0.1570 - learning_rate: 2.5000e-04
# Epoch 233/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9243 - loss: 0.1570 - learning_rate: 2.5000e-04
# Epoch 234/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9242 - loss: 0.1570 - learning_rate: 2.5000e-04
# Epoch 235/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9242 - loss: 0.1569 - learning_rate: 2.5000e-04
# Epoch 236/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9243 - loss: 0.1569 - learning_rate: 2.5000e-04
# Epoch 237/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9243 - loss: 0.1569 - learning_rate: 2.5000e-04
# Epoch 238/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9242 - loss: 0.1569 - learning_rate: 2.5000e-04
# Epoch 239/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9243 - loss: 0.1568 - learning_rate: 2.5000e-04
# Epoch 240/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9243 - loss: 0.1568 - learning_rate: 2.5000e-04
# Epoch 241/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9243 - loss: 0.1568 - learning_rate: 2.5000e-04
# Epoch 242/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9244 - loss: 0.1568 - learning_rate: 2.5000e-04
# Epoch 243/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9242 - loss: 0.1567 - learning_rate: 2.5000e-04
# Epoch 244/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9244 - loss: 0.1567 - learning_rate: 2.5000e-04
# Epoch 245/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9243 - loss: 0.1567 - learning_rate: 2.5000e-04
# Epoch 246/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9243 - loss: 0.1567 - learning_rate: 2.5000e-04
# Epoch 247/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9243 - loss: 0.1567 - learning_rate: 2.5000e-04
# Epoch 248/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9243 - loss: 0.1566 - learning_rate: 2.5000e-04
# Epoch 249/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9244 - loss: 0.1566 - learning_rate: 2.5000e-04
# Epoch 250/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9244 - loss: 0.1566 - learning_rate: 2.5000e-04
# Epoch 251/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9244 - loss: 0.1566 - learning_rate: 2.5000e-04
# Epoch 252/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9243 - loss: 0.1565 - learning_rate: 2.5000e-04
# Epoch 253/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9243 - loss: 0.1565 - learning_rate: 2.5000e-04
# Epoch 254/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9242 - loss: 0.1565 - learning_rate: 2.5000e-04
# Epoch 255/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9243 - loss: 0.1565 - learning_rate: 2.5000e-04
# Epoch 256/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9243 - loss: 0.1565 - learning_rate: 2.5000e-04
# Epoch 257/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9243 - loss: 0.1564 - learning_rate: 2.5000e-04
# Epoch 258/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9242 - loss: 0.1564 - learning_rate: 2.5000e-04
# Epoch 259/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1564 - learning_rate: 2.5000e-04
# Epoch 260/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1564 - learning_rate: 2.5000e-04
# Epoch 261/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1563 - learning_rate: 2.5000e-04
# Epoch 262/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9241 - loss: 0.1563 - learning_rate: 2.5000e-04
# Epoch 263/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1563 - learning_rate: 2.5000e-04
# Epoch 264/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1563 - learning_rate: 2.5000e-04
# Epoch 265/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1563 - learning_rate: 2.5000e-04
# Epoch 266/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1562 - learning_rate: 2.5000e-04
# Epoch 267/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9241 - loss: 0.1562 - learning_rate: 2.5000e-04
# Epoch 268/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1562 - learning_rate: 2.5000e-04
# Epoch 269/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1562 - learning_rate: 2.5000e-04
# Epoch 270/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1562 - learning_rate: 2.5000e-04
# Epoch 271/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9242 - loss: 0.1561 - learning_rate: 2.5000e-04
# Epoch 272/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1561 - learning_rate: 2.5000e-04
# Epoch 273/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9242 - loss: 0.1561 - learning_rate: 2.5000e-04
# Epoch 274/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1561 - learning_rate: 2.5000e-04
# Epoch 275/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9241 - loss: 0.1561 - learning_rate: 2.5000e-04
# Epoch 276/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9242 - loss: 0.1560 - learning_rate: 2.5000e-04
# Epoch 277/300
# 316/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9227 - loss: 0.1564
# Epoch 277: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9242 - loss: 0.1560 - learning_rate: 2.5000e-04
# Epoch 278/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9250 - loss: 0.1552 - learning_rate: 1.2500e-04
# Epoch 279/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9249 - loss: 0.1551 - learning_rate: 1.2500e-04
# Epoch 280/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9249 - loss: 0.1551 - learning_rate: 1.2500e-04
# Epoch 281/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9249 - loss: 0.1551 - learning_rate: 1.2500e-04
# Epoch 282/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9250 - loss: 0.1551 - learning_rate: 1.2500e-04
# Epoch 283/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9249 - loss: 0.1550 - learning_rate: 1.2500e-04
# Epoch 284/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9250 - loss: 0.1550 - learning_rate: 1.2500e-04
# Epoch 285/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9250 - loss: 0.1550 - learning_rate: 1.2500e-04
# Epoch 286/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9249 - loss: 0.1550 - learning_rate: 1.2500e-04
# Epoch 287/300
# 293/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9229 - loss: 0.1555
# Epoch 287: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9249 - loss: 0.1550 - learning_rate: 1.2500e-04
# Epoch 288/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9256 - loss: 0.1545 - learning_rate: 6.2500e-05
# Epoch 289/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9256 - loss: 0.1545 - learning_rate: 6.2500e-05
# Epoch 290/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9254 - loss: 0.1545 - learning_rate: 6.2500e-05
# Epoch 291/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9254 - loss: 0.1545 - learning_rate: 6.2500e-05
# Epoch 292/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9254 - loss: 0.1545 - learning_rate: 6.2500e-05
# Epoch 293/300
# 293/320 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9235 - loss: 0.1551
# Epoch 293: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9254 - loss: 0.1545 - learning_rate: 6.2500e-05
# Epoch 294/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9256 - loss: 0.1543 - learning_rate: 3.1250e-05
# Epoch 295/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9256 - loss: 0.1542 - learning_rate: 3.1250e-05
# Epoch 296/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9256 - loss: 0.1542 - learning_rate: 3.1250e-05
# Epoch 297/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9256 - loss: 0.1542 - learning_rate: 3.1250e-05
# Epoch 298/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9256 - loss: 0.1542 - learning_rate: 3.1250e-05
# Epoch 299/300
# 312/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9236 - loss: 0.1548
# Epoch 299: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9256 - loss: 0.1542 - learning_rate: 3.1250e-05
# Epoch 300/300
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9256 - loss: 0.1541 - learning_rate: 1.5625e-05

# %% [markdown]
# # Plot training history

# %%
epochs = np.arange(1, len(history.history['loss']) + 1)

pl.plot(epochs, history.history['loss'], label='Training Loss')
if 'val_loss' in history.history:
    pl.plot(epochs, history.history['val_loss'], label='Validation Loss')

pl.xlabel('Epochs')
pl.ylabel('Loss')
pl.legend()
pl.show()

# %% [markdown]
# # Performances

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, f1_score
import seaborn as sns

class_names = ["Awake", "REM", "Non-REM"]

def plot_confusion_matrix(confusion_matrix, title):
    # Plot confusion matrix
    pl.figure(figsize=(8, 6))
    sns.heatmap(confusion_matrix.astype(int), annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=class_names, yticklabels=class_names)
    pl.title(title)
    pl.xlabel('Predicted')
    pl.ylabel('True')
    pl.show()

predictions = np.argmax(mlp.predict(val_input), axis=1)

predicted_counts = np.bincount(predictions, minlength=len(class_names))
print("Predicted samples per class on EEG_mouse_data_test.csv:")
for i, class_name in enumerate(class_names):
    print(f"{class_name}: {predicted_counts[i]}")

class_to_state = {0: "w", 1: "r", 2: "n"}
predicted_states = np.array([class_to_state[int(p)] for p in predictions])

test_feature_columns = list(mouse1.columns[1:11])
predicted_test_df = pd.DataFrame(test_data[:, :10], columns=test_feature_columns)
predicted_test_df.insert(0, "state", predicted_states)
# Out:
# 2504/2504 ━━━━━━━━━━━━━━━━━━━━ 2s 674us/step
# Predicted samples per class on EEG_mouse_data_test.csv:
# Awake: 43417
# REM: 6792
# Non-REM: 29900
# Exported predicted test dataset to EEG_mouse_data_test_with_predicted_state.csv

# %%
# Save predictions to test_pred.npy
with open('test_pred.npy', 'wb') as f:
    np.save(f, predicted_states)

print(f"Predictions saved to test_pred.npy")
print(f"Shape: {predicted_states.shape}")
print(f"Data type: {predicted_states.dtype}")
print(f"First 20 predictions: {predicted_states[:20]}")
print(f"Unique values: {np.unique(predicted_states)}")
# Out:
# Predictions saved to test_pred.npy
# Shape: (80109,)
# Data type: <U1
# First 20 predictions: ['n' 'w' 'n' 'n' 'n' 'n' 'n' 'n' 'n' 'n' 'n' 'n' 'w' 'n' 'w' 'w' 'w' 'w'
#  'w' 'w']
# Unique values: ['n' 'r' 'w']
