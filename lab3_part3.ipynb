# %% [markdown]
# # Practical Work 3

# %% [markdown]
# ## Loading the packages

# %%
import numpy as np
import matplotlib.pyplot as pl ## hello

# %% [markdown]
# ## The Dataset

# %%
# %pip install ipympl
# Out:
# /home/yomaru/HEIG/arn/ARN-PW3/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

 # Change this to any folder where data is if needed
mouse1 = pd.read_csv('EEG_mouse_data_1.csv')
mouse2 = pd.read_csv('EEG_mouse_data_2.csv')
dataset = pd.concat([mouse1, mouse2])
test_data = pd.read_csv('EEG_mouse_data_test.csv')
dataset
# Out:
#       state  amplitude_around_1_Hertz  amplitude_around_2_Hertz  \
# 0         n                  0.000009                  0.000014
# 1         n                  0.000010                  0.000010
# 2         n                  0.000011                  0.000077
# 3         w                  0.000003                  0.000031
# 4         w                  0.000010                  0.000011
# ...     ...                       ...                       ...
# 20600     w                  0.000025                  0.000007
# 20601     w                  0.000017                  0.000038
# 20602     w                  0.000016                  0.000028
# 20603     w                  0.000013                  0.000014
# 20604     w                  0.000004                  0.000006
#
#        amplitude_around_3_Hertz  amplitude_around_4_Hertz  \
# 0                      0.000013                  0.000014
# 1                      0.000011                  0.000015
# 2                      0.000034                  0.000019
# 3                      0.000044                  0.000016
# 4                      0.000012                  0.000017
# ...                         ...                       ...
# 20600                  0.000007                  0.000003
# 20601                  0.000015                  0.000011
# 20602                  0.000031                  0.000011
# 20603                  0.000020                  0.000018
# 20604                  0.000011                  0.000025
#
#        amplitude_around_5_Hertz  amplitude_around_6_Hertz  \
# 0                      0.000023                  0.000009
# 1                      0.000022                  0.000017
# 2                      0.000013                  0.000006
# 3                      0.000007                  0.000006
# 4                      0.000020                  0.000018
# ...                         ...                       ...
# 20600                  0.000005                  0.000002
# 20601                  0.000019                  0.000006
# 20602                  0.000019                  0.000001
# 20603                  0.000007                  0.000013
# 20604                  0.000040                  0.000007
#
#        amplitude_around_7_Hertz  amplitude_around_8_Hertz  \
# 0                      0.000019                  0.000011
# 1                      0.000027                  0.000011
# 2                      0.000010                  0.000004
# 3                      0.000005                  0.000007
# 4                      0.000014                  0.000025
# ...                         ...                       ...
# 20600                  0.000005                  0.000010
# 20601                  0.000010                  0.000012
# 20602                  0.000015                  0.000002
# 20603                  0.000009                  0.000018
# 20604                  0.000005                  0.000021
#
#        amplitude_around_9_Hertz  ...  amplitude_around_92_Hertz  \
# 0                      0.000016  ...               8.364060e-09
# 1                      0.000011  ...               6.695745e-09
# 2                      0.000006  ...               1.105705e-08
# 3                      0.000006  ...               2.223992e-08
# 4                      0.000018  ...               6.541705e-09
# ...                         ...  ...                        ...
# 20600                  0.000013  ...               1.162051e-08
# 20601                  0.000009  ...               1.456810e-08
# 20602                  0.000007  ...               1.197483e-08
# 20603                  0.000005  ...               3.028127e-08
# 20604                  0.000011  ...               1.434414e-08
#
#        amplitude_around_93_Hertz  amplitude_around_94_Hertz  \
# 0                   4.208368e-09               2.177679e-09
# 1                   1.213822e-08               2.287185e-08
# 2                   3.264479e-09               1.204057e-09
# 3                   1.028462e-08               3.561479e-09
# 4                   3.312024e-09               8.779863e-09
# ...                          ...                        ...
# 20600               9.470367e-09               1.542617e-08
# 20601               9.259630e-09               3.831858e-08
# 20602               2.496412e-08               2.292325e-08
# 20603               9.760537e-09               3.475243e-09
# 20604               1.081698e-08               6.120670e-09
#
#        amplitude_around_95_Hertz  amplitude_around_96_Hertz  \
# 0                   4.342505e-09               5.130010e-09
# 1                   3.219380e-09               2.461736e-09
# 2                   5.090074e-09               5.477467e-09
# 3                   3.704753e-09               2.425319e-09
# 4                   7.400000e-09               2.890853e-09
# ...                          ...                        ...
# 20600               6.114029e-09               2.346950e-09
# 20601               3.839020e-09               4.668449e-09
# 20602               2.783310e-09               6.423075e-09
# 20603               2.667755e-09               4.243288e-09
# 20604               4.113743e-09               6.910015e-09
#
#        amplitude_around_97_Hertz  amplitude_around_98_Hertz  \
# 0                   2.852361e-09               9.772395e-10
# 1                   2.985953e-09               1.434412e-09
# 2                   1.809223e-09               7.064289e-10
# 3                   1.536834e-09               2.540238e-10
# 4                   5.709757e-10               2.171227e-09
# ...                          ...                        ...
# 20600               4.264138e-09               1.733832e-09
# 20601               1.671207e-09               2.347928e-09
# 20602               3.649511e-09               4.350072e-09
# 20603               6.048632e-09               3.234623e-09
# 20604               7.412423e-09               3.527602e-09
#
#        amplitude_around_99_Hertz  amplitude_around_100_Hertz  \
# 0                   1.876307e-09                5.457793e-09
# 1                   1.579590e-09                5.458902e-09
# 2                   1.435585e-09                7.416121e-09
# 3                   6.300358e-10                3.647454e-09
# 4                   6.757242e-10                2.005702e-09
# ...                          ...                         ...
# 20600               8.314190e-10                1.720087e-09
# 20601               2.219437e-09                2.045267e-09
# 20602               6.656486e-10                2.086456e-09
# 20603               1.421633e-09                9.709723e-10
# 20604               2.895608e-09                4.211010e-09
#
#        amplitude_around_101_Hertz
# 0                    8.653900e-08
# 1                    8.492570e-08
# 2                    1.156240e-07
# 3                    2.212800e-08
# 4                    2.861980e-10
# ...                           ...
# 20600                1.345590e-09
# 20601                6.063210e-09
# 20602                2.761580e-08
# 20603                2.062290e-08
# 20604                3.054510e-08
#
# [40863 rows x 102 columns]

# %% [markdown]
# ## Show the dataset

# %%
dataset = np.array(dataset)
test_data = np.array(test_data)
dataset
# Out:
# array([['n', 9.123150377376987e-06, 1.3656147984875132e-05, ...,
#         1.8763067211047253e-09, 5.457792863483579e-09,
#         8.653900351873746e-08],
#        ['n', 9.79506089393567e-06, 9.573940179308238e-06, ...,
#         1.5795897784220971e-09, 5.4589015668904395e-09,
#         8.492570202633942e-08],
#        ['n', 1.0809589923610474e-05, 7.670862305531045e-05, ...,
#         1.435585247899773e-09, 7.4161209742684706e-09,
#         1.1562399748754617e-07],
#        ...,
#        ['w', 1.6213877302106994e-05, 2.8464069458777885e-05, ...,
#         6.656486386397154e-10, 2.08645636011473e-09,
#         2.7615799425007026e-08],
#        ['w', 1.2860698049621533e-05, 1.3600040119854384e-05, ...,
#         1.421632783715765e-09, 9.70972280009419e-10,
#         2.062290072046835e-08],
#        ['w', 3.5420524397977715e-06, 5.874647627024388e-06, ...,
#         2.8956081976616584e-09, 4.211009985155556e-09,
#         3.054509889466317e-08]], shape=(40863, 102), dtype=object)

# %%
input_data = dataset[:, 1:11].astype(float)
feature_mean = input_data.mean(axis=0)
feature_std = input_data.std(axis=0) + 1e-8
input_data = (input_data - feature_mean) / feature_std  # Standardize each feature

state_to_class = {"w": 0, "r": 1, "n": 2}
output_data = np.array([state_to_class[state] for state in dataset[:, 0]], dtype=int)

temporal_window = 4

def make_past_context_features(X, window=4):
    # Builds [x(t-window), ..., x(t-1), x(t)] for each sample at time t
    n, d = X.shape
    context_parts = []
    for lag in range(window, 0, -1):
        shifted = np.empty_like(X)
        shifted[:lag] = X[0]
        shifted[lag:] = X[:-lag]
        context_parts.append(shifted)
    context_parts.append(X)
    return np.hstack(context_parts)

model_input_data = make_past_context_features(input_data, window=temporal_window)

# test_data has only features (no state column in EEG_mouse_data_test.csv)
test_input_data = test_data[:, :10].astype(float)
test_input_data = (test_input_data - feature_mean) / feature_std
test_model_input_data = make_past_context_features(test_input_data, window=temporal_window)

val_input = test_model_input_data
val_output = None

# %%
input_data
# Out:
# array([[-0.20987265, -0.08194901, -0.1050478 , ..., -0.12720215,
#          0.70849675,  1.30767881],
#        [-0.1833618 , -0.32559618, -0.23035843, ..., -0.1001689 ,
#          0.09924395,  0.25545035],
#        [-0.14333261,  3.68134731,  1.38922012, ..., -0.7483781 ,
#         -0.45690898, -0.72108948],
#        ...,
#        [ 0.06989857,  0.80186398,  1.18418179, ..., -0.92162007,
#         -0.29742897, -0.90504528],
#        [-0.06240423, -0.08529781,  0.37567232, ...,  0.54767347,
#         -0.59646021, -0.69274525],
#        [-0.43008006, -0.54638901, -0.24674486, ...,  0.81216587,
#          0.09678055,  0.04914934]], shape=(40863, 10))

# %%
output_data
# Out:
# array([2, 2, 2, ..., 0, 0, 0], shape=(40863,))

# %%
# Check data balance
class_names = ["Awake", "REM", "Non-REM"]
unique, counts = np.unique(output_data, return_counts=True)
for label, count in zip(unique, counts):
    state = class_names[label]
    print(f"{state}: {count} samples ({count/len(output_data)*100:.1f}%)")
# Out:
# Awake: 24360 samples (59.6%)
# REM: 2839 samples (6.9%)
# Non-REM: 13664 samples (33.4%)

# %%
# %matplotlib inline

# %%
import keras
from keras import layers

pl.clf()

keras.utils.set_random_seed(123)

class_colors = {0: "tab:blue", 1: "tab:orange", 2: "tab:green"}
validation_color = "lightgray"
class_names = ["Awake", "REM", "Non-REM"]

pl.figure(figsize=(4,4))

# Plot train data and validation data
pl.scatter(input_data[:,0], input_data[:,1], c=[class_colors[int(d)] for d in output_data], s=100)
#pl.scatter(val_input[:,0], val_input[:,1], c=validation_color, s=100)
pl.title('Training data (colored)')
pl.show()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775113491.347115   43031 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1775113491.385869   43031 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775113492.482342   43031 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
MODEL_CONFIG = {
  "input_dim": 50,
  "hidden_units": [32],
  "learning_rate": 0.1,
  "batch_size": 32,
  "epochs": 300,
  "early_stopping_patience": 15,
  "reduce_lr_patience": 5,
  "reduce_lr_factor": 0.5,
  "min_lr": 1e-5,
}

def create_model(config=MODEL_CONFIG):
  # Keep this config aligned with the folds notebook
  mlp = keras.Sequential()
  mlp.add(layers.Input(shape=(config["input_dim"],)))

  for units in config["hidden_units"]:
      mlp.add(layers.Dense(units, activation="relu"))

  mlp.add(layers.Dense(3, activation="softmax"))

  mlp.compile(
      optimizer=keras.optimizers.SGD(learning_rate=config["learning_rate"], momentum=0.8),
      loss="sparse_categorical_crossentropy",
      metrics=["accuracy"],
  )

  return mlp

mlp = create_model()
print("MODEL_CONFIG:", MODEL_CONFIG)
mlp.summary()
# Out:
# MODEL_CONFIG: {'input_dim': 50, 'hidden_units': [32], 'learning_rate': 0.1, 'batch_size': 32, 'epochs': 300, 'early_stopping_patience': 15, 'reduce_lr_patience': 5, 'reduce_lr_factor': 0.5, 'min_lr': 1e-05}
# E0000 00:00:1775113494.212819   43031 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1775113494.225341   43031 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │         1,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,731 (6.76 KB)
#  Trainable params: 1,731 (6.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

monitor_metric = "val_loss" if val_output is not None else "loss"

early_stopping = EarlyStopping(
    monitor=monitor_metric,
    patience=MODEL_CONFIG["early_stopping_patience"],
    min_delta=1e-4,
    restore_best_weights=True,
)
reduce_lr = ReduceLROnPlateau(
    monitor=monitor_metric,
    factor=MODEL_CONFIG["reduce_lr_factor"],
    patience=MODEL_CONFIG["reduce_lr_patience"],
    min_delta=1e-4,
    min_lr=MODEL_CONFIG["min_lr"],
    verbose=1,
)

mlp = create_model()

class_values = np.unique(output_data)
class_weights = compute_class_weight(class_weight="balanced", classes=class_values, y=output_data)
class_weights = np.sqrt(class_weights)
class_weights = class_weights / np.mean(class_weights)
class_weight_dict = dict(zip(class_values, class_weights))

fit_kwargs = dict(
    x=model_input_data,
    y=output_data,
    epochs=MODEL_CONFIG["epochs"],
    batch_size=MODEL_CONFIG["batch_size"],
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr],
)

if val_output is not None:
    fit_kwargs["validation_data"] = (val_input, val_output)

history = mlp.fit(**fit_kwargs)
# Out:
# Epoch 1/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8837 - loss: 0.2566 - learning_rate: 0.1000
# Epoch 2/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8910 - loss: 0.2467 - learning_rate: 0.1000
# Epoch 3/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8940 - loss: 0.2362 - learning_rate: 0.1000
# Epoch 4/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8969 - loss: 0.2278 - learning_rate: 0.1000
# Epoch 5/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8963 - loss: 0.2276 - learning_rate: 0.1000
# Epoch 6/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8965 - loss: 0.2307 - learning_rate: 0.1000
# Epoch 7/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8985 - loss: 0.2266 - learning_rate: 0.1000
# Epoch 8/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8983 - loss: 0.2289 - learning_rate: 0.1000
# Epoch 9/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8977 - loss: 0.2259 - learning_rate: 0.1000
# Epoch 10/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8986 - loss: 0.2289 - learning_rate: 0.1000
# Epoch 11/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8992 - loss: 0.2308 - learning_rate: 0.1000
# Epoch 12/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9003 - loss: 0.2209 - learning_rate: 0.1000
# Epoch 13/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9016 - loss: 0.2228 - learning_rate: 0.1000
# Epoch 14/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9027 - loss: 0.2161 - learning_rate: 0.1000
# Epoch 15/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9019 - loss: 0.2186 - learning_rate: 0.1000
# Epoch 16/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9021 - loss: 0.2234 - learning_rate: 0.1000
# Epoch 17/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9003 - loss: 0.2260 - learning_rate: 0.1000
# Epoch 18/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9009 - loss: 0.2187 - learning_rate: 0.1000
# Epoch 19/300
# 1237/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8998 - loss: 0.2226
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9012 - loss: 0.2186 - learning_rate: 0.1000
# Epoch 20/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9101 - loss: 0.1963 - learning_rate: 0.0500
# Epoch 21/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9111 - loss: 0.1926 - learning_rate: 0.0500
# Epoch 22/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9115 - loss: 0.1896 - learning_rate: 0.0500
# Epoch 23/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9111 - loss: 0.1901 - learning_rate: 0.0500
# Epoch 24/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9110 - loss: 0.1889 - learning_rate: 0.0500
# Epoch 25/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9117 - loss: 0.1889 - learning_rate: 0.0500
# Epoch 26/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9119 - loss: 0.1874 - learning_rate: 0.0500
# Epoch 27/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9128 - loss: 0.1858 - learning_rate: 0.0500
# Epoch 28/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9132 - loss: 0.1851 - learning_rate: 0.0500
# Epoch 29/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9137 - loss: 0.1831 - learning_rate: 0.0500
# Epoch 30/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9140 - loss: 0.1828 - learning_rate: 0.0500
# Epoch 31/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9143 - loss: 0.1835 - learning_rate: 0.0500
# Epoch 32/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9147 - loss: 0.1850 - learning_rate: 0.0500
# Epoch 33/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9141 - loss: 0.1856 - learning_rate: 0.0500
# Epoch 34/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9144 - loss: 0.1870 - learning_rate: 0.0500
# Epoch 35/300
# 1271/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9147 - loss: 0.1859
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9147 - loss: 0.1828 - learning_rate: 0.0500
# Epoch 36/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9193 - loss: 0.1722 - learning_rate: 0.0250
# Epoch 37/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9192 - loss: 0.1705 - learning_rate: 0.0250
# Epoch 38/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9193 - loss: 0.1695 - learning_rate: 0.0250
# Epoch 39/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9200 - loss: 0.1677 - learning_rate: 0.0250
# Epoch 40/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9204 - loss: 0.1680 - learning_rate: 0.0250
# Epoch 41/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9203 - loss: 0.1684 - learning_rate: 0.0250
# Epoch 42/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9203 - loss: 0.1685 - learning_rate: 0.0250
# Epoch 43/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9205 - loss: 0.1663 - learning_rate: 0.0250
# Epoch 44/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9207 - loss: 0.1661 - learning_rate: 0.0250
# Epoch 45/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9206 - loss: 0.1671 - learning_rate: 0.0250
# Epoch 46/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9207 - loss: 0.1656 - learning_rate: 0.0250
# Epoch 47/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9205 - loss: 0.1690 - learning_rate: 0.0250
# Epoch 48/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9209 - loss: 0.1652 - learning_rate: 0.0250
# Epoch 49/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9207 - loss: 0.1650 - learning_rate: 0.0250
# Epoch 50/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9212 - loss: 0.1661 - learning_rate: 0.0250
# Epoch 51/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9212 - loss: 0.1650 - learning_rate: 0.0250
# Epoch 52/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9210 - loss: 0.1645 - learning_rate: 0.0250
# Epoch 53/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9215 - loss: 0.1651 - learning_rate: 0.0250
# Epoch 54/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9215 - loss: 0.1656 - learning_rate: 0.0250
# Epoch 55/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9207 - loss: 0.1659 - learning_rate: 0.0250
# Epoch 56/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9217 - loss: 0.1638 - learning_rate: 0.0250
# Epoch 57/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9213 - loss: 0.1639 - learning_rate: 0.0250
# Epoch 58/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9214 - loss: 0.1653 - learning_rate: 0.0250
# Epoch 59/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9208 - loss: 0.1638 - learning_rate: 0.0250
# Epoch 60/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9213 - loss: 0.1648 - learning_rate: 0.0250
# Epoch 61/300
# 1264/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9210 - loss: 0.1680
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9221 - loss: 0.1648 - learning_rate: 0.0250
# Epoch 62/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9235 - loss: 0.1583 - learning_rate: 0.0125
# Epoch 63/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9241 - loss: 0.1573 - learning_rate: 0.0125
# Epoch 64/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9241 - loss: 0.1570 - learning_rate: 0.0125
# Epoch 65/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9241 - loss: 0.1568 - learning_rate: 0.0125
# Epoch 66/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9240 - loss: 0.1566 - learning_rate: 0.0125
# Epoch 67/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9242 - loss: 0.1564 - learning_rate: 0.0125
# Epoch 68/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9243 - loss: 0.1562 - learning_rate: 0.0125
# Epoch 69/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9243 - loss: 0.1562 - learning_rate: 0.0125
# Epoch 70/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9244 - loss: 0.1560 - learning_rate: 0.0125
# Epoch 71/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9243 - loss: 0.1560 - learning_rate: 0.0125
# Epoch 72/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9242 - loss: 0.1558 - learning_rate: 0.0125
# Epoch 73/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9243 - loss: 0.1558 - learning_rate: 0.0125
# Epoch 74/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9243 - loss: 0.1557 - learning_rate: 0.0125
# Epoch 75/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9243 - loss: 0.1556 - learning_rate: 0.0125
# Epoch 76/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9246 - loss: 0.1555 - learning_rate: 0.0125
# Epoch 77/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9246 - loss: 0.1554 - learning_rate: 0.0125
# Epoch 78/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9244 - loss: 0.1554 - learning_rate: 0.0125
# Epoch 79/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9247 - loss: 0.1552 - learning_rate: 0.0125
# Epoch 80/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9246 - loss: 0.1551 - learning_rate: 0.0125
# Epoch 81/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9245 - loss: 0.1551 - learning_rate: 0.0125
# Epoch 82/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9247 - loss: 0.1551 - learning_rate: 0.0125
# Epoch 83/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9244 - loss: 0.1557 - learning_rate: 0.0125
# Epoch 84/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9247 - loss: 0.1554 - learning_rate: 0.0125
# Epoch 85/300
# 1253/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9245 - loss: 0.1556
# Epoch 85: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9245 - loss: 0.1552 - learning_rate: 0.0125
# Epoch 86/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9261 - loss: 0.1527 - learning_rate: 0.0063
# Epoch 87/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9262 - loss: 0.1522 - learning_rate: 0.0063
# Epoch 88/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9264 - loss: 0.1520 - learning_rate: 0.0063
# Epoch 89/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9264 - loss: 0.1519 - learning_rate: 0.0063
# Epoch 90/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9263 - loss: 0.1518 - learning_rate: 0.0063
# Epoch 91/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9264 - loss: 0.1517 - learning_rate: 0.0063
# Epoch 92/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9263 - loss: 0.1517 - learning_rate: 0.0063
# Epoch 93/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9265 - loss: 0.1516 - learning_rate: 0.0063
# Epoch 94/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9262 - loss: 0.1516 - learning_rate: 0.0063
# Epoch 95/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9263 - loss: 0.1515 - learning_rate: 0.0063
# Epoch 96/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9262 - loss: 0.1515 - learning_rate: 0.0063
# Epoch 97/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9262 - loss: 0.1515 - learning_rate: 0.0063
# Epoch 98/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9261 - loss: 0.1514 - learning_rate: 0.0063
# Epoch 99/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9259 - loss: 0.1514 - learning_rate: 0.0063
# Epoch 100/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9258 - loss: 0.1514 - learning_rate: 0.0063
# Epoch 101/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9260 - loss: 0.1514 - learning_rate: 0.0063
# Epoch 102/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9260 - loss: 0.1513 - learning_rate: 0.0063
# Epoch 103/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9260 - loss: 0.1513 - learning_rate: 0.0063
# Epoch 104/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9259 - loss: 0.1513 - learning_rate: 0.0063
# Epoch 105/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9260 - loss: 0.1512 - learning_rate: 0.0063
# Epoch 106/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9260 - loss: 0.1512 - learning_rate: 0.0063
# Epoch 107/300
# 1276/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9263 - loss: 0.1513
# Epoch 107: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9261 - loss: 0.1512 - learning_rate: 0.0063
# Epoch 108/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9272 - loss: 0.1499 - learning_rate: 0.0031
# Epoch 109/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9273 - loss: 0.1497 - learning_rate: 0.0031
# Epoch 110/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9272 - loss: 0.1496 - learning_rate: 0.0031
# Epoch 111/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9273 - loss: 0.1496 - learning_rate: 0.0031
# Epoch 112/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9274 - loss: 0.1496 - learning_rate: 0.0031
# Epoch 113/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9273 - loss: 0.1495 - learning_rate: 0.0031
# Epoch 114/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9273 - loss: 0.1495 - learning_rate: 0.0031
# Epoch 115/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9273 - loss: 0.1495 - learning_rate: 0.0031
# Epoch 116/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9273 - loss: 0.1495 - learning_rate: 0.0031
# Epoch 117/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9273 - loss: 0.1495 - learning_rate: 0.0031
# Epoch 118/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9272 - loss: 0.1495 - learning_rate: 0.0031
# Epoch 119/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9273 - loss: 0.1494 - learning_rate: 0.0031
# Epoch 120/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9273 - loss: 0.1494 - learning_rate: 0.0031
# Epoch 121/300
# 1257/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9265 - loss: 0.1495
# Epoch 121: ReduceLROnPlateau reducing learning rate to 0.0015625000232830644.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9274 - loss: 0.1494 - learning_rate: 0.0031
# Epoch 122/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9275 - loss: 0.1487 - learning_rate: 0.0016
# Epoch 123/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9276 - loss: 0.1486 - learning_rate: 0.0016
# Epoch 124/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9275 - loss: 0.1486 - learning_rate: 0.0016
# Epoch 125/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9276 - loss: 0.1486 - learning_rate: 0.0016
# Epoch 126/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9275 - loss: 0.1485 - learning_rate: 0.0016
# Epoch 127/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9275 - loss: 0.1485 - learning_rate: 0.0016
# Epoch 128/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9275 - loss: 0.1485 - learning_rate: 0.0016
# Epoch 129/300
# 1265/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9265 - loss: 0.1487
# Epoch 129: ReduceLROnPlateau reducing learning rate to 0.0007812500116415322.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9274 - loss: 0.1485 - learning_rate: 0.0016
# Epoch 130/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9278 - loss: 0.1481 - learning_rate: 7.8125e-04
# Epoch 131/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9279 - loss: 0.1481 - learning_rate: 7.8125e-04
# Epoch 132/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9281 - loss: 0.1481 - learning_rate: 7.8125e-04
# Epoch 133/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9281 - loss: 0.1481 - learning_rate: 7.8125e-04
# Epoch 134/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9280 - loss: 0.1480 - learning_rate: 7.8125e-04
# Epoch 135/300
# 1252/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9270 - loss: 0.1483
# Epoch 135: ReduceLROnPlateau reducing learning rate to 0.0003906250058207661.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9281 - loss: 0.1480 - learning_rate: 7.8125e-04
# Epoch 136/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9281 - loss: 0.1478 - learning_rate: 3.9063e-04
# Epoch 137/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9282 - loss: 0.1478 - learning_rate: 3.9063e-04
# Epoch 138/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9281 - loss: 0.1478 - learning_rate: 3.9063e-04
# Epoch 139/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9281 - loss: 0.1478 - learning_rate: 3.9063e-04
# Epoch 140/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9281 - loss: 0.1478 - learning_rate: 3.9063e-04
# Epoch 141/300
# 1276/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9271 - loss: 0.1481
# Epoch 141: ReduceLROnPlateau reducing learning rate to 0.00019531250291038305.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9281 - loss: 0.1478 - learning_rate: 3.9063e-04
# Epoch 142/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9282 - loss: 0.1477 - learning_rate: 1.9531e-04
# Epoch 143/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9282 - loss: 0.1477 - learning_rate: 1.9531e-04
# Epoch 144/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9282 - loss: 0.1477 - learning_rate: 1.9531e-04
# Epoch 145/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9283 - loss: 0.1477 - learning_rate: 1.9531e-04
# Epoch 146/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9283 - loss: 0.1477 - learning_rate: 1.9531e-04
# Epoch 147/300
# 1249/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9272 - loss: 0.1480
# Epoch 147: ReduceLROnPlateau reducing learning rate to 9.765625145519152e-05.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9283 - loss: 0.1477 - learning_rate: 1.9531e-04
# Epoch 148/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1476 - learning_rate: 9.7656e-05
# Epoch 149/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1476 - learning_rate: 9.7656e-05
# Epoch 150/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1476 - learning_rate: 9.7656e-05
# Epoch 151/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1476 - learning_rate: 9.7656e-05
# Epoch 152/300
# 1256/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9273 - loss: 0.1479
# Epoch 152: ReduceLROnPlateau reducing learning rate to 4.882812572759576e-05.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1476 - learning_rate: 9.7656e-05
# Epoch 153/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 4.8828e-05
# Epoch 154/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 4.8828e-05
# Epoch 155/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 4.8828e-05
# Epoch 156/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 4.8828e-05
# Epoch 157/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 4.8828e-05
# Epoch 158/300
# 1238/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9273 - loss: 0.1479
# Epoch 158: ReduceLROnPlateau reducing learning rate to 2.441406286379788e-05.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 4.8828e-05
# Epoch 159/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 2.4414e-05
# Epoch 160/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 2.4414e-05
# Epoch 161/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 2.4414e-05
# Epoch 162/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 2.4414e-05
# Epoch 163/300
# 1244/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9273 - loss: 0.1479
# Epoch 163: ReduceLROnPlateau reducing learning rate to 1.220703143189894e-05.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 2.4414e-05
# Epoch 164/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 1.2207e-05
# Epoch 165/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 1.2207e-05
# Epoch 166/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 1.2207e-05
# Epoch 167/300
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 1.2207e-05
# Epoch 168/300
# 1248/1277 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9273 - loss: 0.1479
# Epoch 168: ReduceLROnPlateau reducing learning rate to 1e-05.
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9284 - loss: 0.1475 - learning_rate: 1.2207e-05

# %% [markdown]
# # Plot training history

# %%
epochs = np.arange(1, len(history.history['loss']) + 1)

pl.plot(epochs, history.history['loss'], label='Training Loss')
if 'val_loss' in history.history:
    pl.plot(epochs, history.history['val_loss'], label='Validation Loss')

pl.xlabel('Epochs')
pl.ylabel('Loss')
pl.legend()
pl.show()

# %% [markdown]
# # Performances

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, f1_score
import seaborn as sns

class_names = ["Awake", "REM", "Non-REM"]

def plot_confusion_matrix(confusion_matrix, title):
    # Plot confusion matrix
    pl.figure(figsize=(8, 6))
    sns.heatmap(confusion_matrix.astype(int), annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=class_names, yticklabels=class_names)
    pl.title(title)
    pl.xlabel('Predicted')
    pl.ylabel('True')
    pl.show()

predictions = np.argmax(mlp.predict(val_input), axis=1)

predicted_counts = np.bincount(predictions, minlength=len(class_names))
print("Predicted samples per class on EEG_mouse_data_test.csv:")
for i, class_name in enumerate(class_names):
    print(f"{class_name}: {predicted_counts[i]}")

class_to_state = {0: "w", 1: "r", 2: "n"}
predicted_states = np.array([class_to_state[int(p)] for p in predictions])

test_feature_columns = list(mouse1.columns[1:11])
predicted_test_df = pd.DataFrame(test_data[:, :10], columns=test_feature_columns)
predicted_test_df.insert(0, "state", predicted_states)
# Out:
# 2504/2504 ━━━━━━━━━━━━━━━━━━━━ 1s 558us/step
# Predicted samples per class on EEG_mouse_data_test.csv:
# Awake: 43549
# REM: 6651
# Non-REM: 29909

# %%
# Save predictions to test_pred.npy
with open('test_pred.npy', 'wb') as f:
    np.save(f, predicted_states)

print(f"Predictions saved to test_pred.npy")
print(f"Shape: {predicted_states.shape}")
print(f"Data type: {predicted_states.dtype}")
print(f"First 20 predictions: {predicted_states[:20]}")
print(f"Unique values: {np.unique(predicted_states)}")
# Out:
# Predictions saved to test_pred.npy
# Shape: (80109,)
# Data type: <U1
# First 20 predictions: ['n' 'w' 'n' 'n' 'n' 'n' 'n' 'n' 'n' 'n' 'n' 'w' 'w' 'w' 'w' 'w' 'w' 'w'
#  'r' 'w']
# Unique values: ['n' 'r' 'w']
