# %% [markdown]
# # Practical Work 3

# %% [markdown]
# ## Loading the packages

# %%
import numpy as np
import matplotlib.pyplot as pl ## hello

# %% [markdown]
# ## The Dataset

# %%
# %pip install ipympl
# Out:
# /home/yomaru/HEIG/arn/ARN-PW3/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

 # Change this to any folder where data is if needed
mouse1 = pd.read_csv('EEG_mouse_data_1.csv')
mouse2 = pd.read_csv('EEG_mouse_data_2.csv')
dataset = pd.concat([mouse1, mouse2])
dataset
# Out:
#       state  amplitude_around_1_Hertz  amplitude_around_2_Hertz  \
# 0         n                  0.000009                  0.000014
# 1         n                  0.000010                  0.000010
# 2         n                  0.000011                  0.000077
# 3         w                  0.000003                  0.000031
# 4         w                  0.000010                  0.000011
# ...     ...                       ...                       ...
# 20600     w                  0.000025                  0.000007
# 20601     w                  0.000017                  0.000038
# 20602     w                  0.000016                  0.000028
# 20603     w                  0.000013                  0.000014
# 20604     w                  0.000004                  0.000006
#
#        amplitude_around_3_Hertz  amplitude_around_4_Hertz  \
# 0                      0.000013                  0.000014
# 1                      0.000011                  0.000015
# 2                      0.000034                  0.000019
# 3                      0.000044                  0.000016
# 4                      0.000012                  0.000017
# ...                         ...                       ...
# 20600                  0.000007                  0.000003
# 20601                  0.000015                  0.000011
# 20602                  0.000031                  0.000011
# 20603                  0.000020                  0.000018
# 20604                  0.000011                  0.000025
#
#        amplitude_around_5_Hertz  amplitude_around_6_Hertz  \
# 0                      0.000023                  0.000009
# 1                      0.000022                  0.000017
# 2                      0.000013                  0.000006
# 3                      0.000007                  0.000006
# 4                      0.000020                  0.000018
# ...                         ...                       ...
# 20600                  0.000005                  0.000002
# 20601                  0.000019                  0.000006
# 20602                  0.000019                  0.000001
# 20603                  0.000007                  0.000013
# 20604                  0.000040                  0.000007
#
#        amplitude_around_7_Hertz  amplitude_around_8_Hertz  \
# 0                      0.000019                  0.000011
# 1                      0.000027                  0.000011
# 2                      0.000010                  0.000004
# 3                      0.000005                  0.000007
# 4                      0.000014                  0.000025
# ...                         ...                       ...
# 20600                  0.000005                  0.000010
# 20601                  0.000010                  0.000012
# 20602                  0.000015                  0.000002
# 20603                  0.000009                  0.000018
# 20604                  0.000005                  0.000021
#
#        amplitude_around_9_Hertz  ...  amplitude_around_92_Hertz  \
# 0                      0.000016  ...               8.364060e-09
# 1                      0.000011  ...               6.695745e-09
# 2                      0.000006  ...               1.105705e-08
# 3                      0.000006  ...               2.223992e-08
# 4                      0.000018  ...               6.541705e-09
# ...                         ...  ...                        ...
# 20600                  0.000013  ...               1.162051e-08
# 20601                  0.000009  ...               1.456810e-08
# 20602                  0.000007  ...               1.197483e-08
# 20603                  0.000005  ...               3.028127e-08
# 20604                  0.000011  ...               1.434414e-08
#
#        amplitude_around_93_Hertz  amplitude_around_94_Hertz  \
# 0                   4.208368e-09               2.177679e-09
# 1                   1.213822e-08               2.287185e-08
# 2                   3.264479e-09               1.204057e-09
# 3                   1.028462e-08               3.561479e-09
# 4                   3.312024e-09               8.779863e-09
# ...                          ...                        ...
# 20600               9.470367e-09               1.542617e-08
# 20601               9.259630e-09               3.831858e-08
# 20602               2.496412e-08               2.292325e-08
# 20603               9.760537e-09               3.475243e-09
# 20604               1.081698e-08               6.120670e-09
#
#        amplitude_around_95_Hertz  amplitude_around_96_Hertz  \
# 0                   4.342505e-09               5.130010e-09
# 1                   3.219380e-09               2.461736e-09
# 2                   5.090074e-09               5.477467e-09
# 3                   3.704753e-09               2.425319e-09
# 4                   7.400000e-09               2.890853e-09
# ...                          ...                        ...
# 20600               6.114029e-09               2.346950e-09
# 20601               3.839020e-09               4.668449e-09
# 20602               2.783310e-09               6.423075e-09
# 20603               2.667755e-09               4.243288e-09
# 20604               4.113743e-09               6.910015e-09
#
#        amplitude_around_97_Hertz  amplitude_around_98_Hertz  \
# 0                   2.852361e-09               9.772395e-10
# 1                   2.985953e-09               1.434412e-09
# 2                   1.809223e-09               7.064289e-10
# 3                   1.536834e-09               2.540238e-10
# 4                   5.709757e-10               2.171227e-09
# ...                          ...                        ...
# 20600               4.264138e-09               1.733832e-09
# 20601               1.671207e-09               2.347928e-09
# 20602               3.649511e-09               4.350072e-09
# 20603               6.048632e-09               3.234623e-09
# 20604               7.412423e-09               3.527602e-09
#
#        amplitude_around_99_Hertz  amplitude_around_100_Hertz  \
# 0                   1.876307e-09                5.457793e-09
# 1                   1.579590e-09                5.458902e-09
# 2                   1.435585e-09                7.416121e-09
# 3                   6.300358e-10                3.647454e-09
# 4                   6.757242e-10                2.005702e-09
# ...                          ...                         ...
# 20600               8.314190e-10                1.720087e-09
# 20601               2.219437e-09                2.045267e-09
# 20602               6.656486e-10                2.086456e-09
# 20603               1.421633e-09                9.709723e-10
# 20604               2.895608e-09                4.211010e-09
#
#        amplitude_around_101_Hertz
# 0                    8.653900e-08
# 1                    8.492570e-08
# 2                    1.156240e-07
# 3                    2.212800e-08
# 4                    2.861980e-10
# ...                           ...
# 20600                1.345590e-09
# 20601                6.063210e-09
# 20602                2.761580e-08
# 20603                2.062290e-08
# 20604                3.054510e-08
#
# [40863 rows x 102 columns]

# %% [markdown]
# <font color="red">**For it to work on Colab, you will need to reload your session (Exécution -> redémarrer la session)**</font>

# %% [markdown]
# <font color="orange">**Make sure to put a large amount of points otherwise the cross validation folds will be really small**</font>

# %% [markdown]
# ## Show the dataset

# %%
dataset = np.array(dataset)
dataset
# Out:
# array([['n', 9.123150377376987e-06, 1.3656147984875132e-05, ...,
#         1.8763067211047253e-09, 5.457792863483579e-09,
#         8.653900351873746e-08],
#        ['n', 9.79506089393567e-06, 9.573940179308238e-06, ...,
#         1.5795897784220971e-09, 5.4589015668904395e-09,
#         8.492570202633942e-08],
#        ['n', 1.0809589923610474e-05, 7.670862305531045e-05, ...,
#         1.435585247899773e-09, 7.4161209742684706e-09,
#         1.1562399748754617e-07],
#        ...,
#        ['w', 1.6213877302106994e-05, 2.8464069458777885e-05, ...,
#         6.656486386397154e-10, 2.08645636011473e-09,
#         2.7615799425007026e-08],
#        ['w', 1.2860698049621533e-05, 1.3600040119854384e-05, ...,
#         1.421632783715765e-09, 9.70972280009419e-10,
#         2.062290072046835e-08],
#        ['w', 3.5420524397977715e-06, 5.874647627024388e-06, ...,
#         2.8956081976616584e-09, 4.211009985155556e-09,
#         3.054509889466317e-08]], shape=(40863, 102), dtype=object)

# %%
input_data = dataset[:, 1:11].astype(float)
input_data = (input_data - input_data.mean(axis=0)) / (input_data.std(axis=0) + 1e-8)  # Standardize each feature
state_to_class = {"w": 0, "r": 1, "n": 2}
output_data = np.array([state_to_class[state] for state in dataset[:, 0]], dtype=int)

temporal_window = 4

def make_past_context_features(X, window=4):
    # Builds [x(t-window), ..., x(t-1), x(t)] for each sample at time t
    n, d = X.shape
    context_parts = []
    for lag in range(window, 0, -1):
        shifted = np.empty_like(X)
        shifted[:lag] = X[0]
        shifted[lag:] = X[:-lag]
        context_parts.append(shifted)
    context_parts.append(X)
    return np.hstack(context_parts)

model_input_data = make_past_context_features(input_data, window=temporal_window)

# %%
input_data
# Out:
# array([[-0.20987265, -0.08194901, -0.1050478 , ..., -0.12720215,
#          0.70849675,  1.30767881],
#        [-0.1833618 , -0.32559618, -0.23035843, ..., -0.1001689 ,
#          0.09924395,  0.25545035],
#        [-0.14333261,  3.68134731,  1.38922012, ..., -0.7483781 ,
#         -0.45690898, -0.72108948],
#        ...,
#        [ 0.06989857,  0.80186398,  1.18418179, ..., -0.92162007,
#         -0.29742897, -0.90504528],
#        [-0.06240423, -0.08529781,  0.37567232, ...,  0.54767347,
#         -0.59646021, -0.69274525],
#        [-0.43008006, -0.54638901, -0.24674486, ...,  0.81216587,
#          0.09678055,  0.04914934]], shape=(40863, 10))

# %%
output_data
# Out:
# array([2, 2, 2, ..., 0, 0, 0], shape=(40863,))

# %%
# Check data balance
class_names = ["Awake", "REM", "Non-REM"]
unique, counts = np.unique(output_data, return_counts=True)
for label, count in zip(unique, counts):
    state = class_names[label]
    print(f"{state}: {count} samples ({count/len(output_data)*100:.1f}%)")
# Out:
# Awake: 24360 samples (59.6%)
# REM: 2839 samples (6.9%)
# Non-REM: 13664 samples (33.4%)

# %%
# %matplotlib inline

# %%
import keras
from keras import layers
from sklearn.model_selection import StratifiedKFold

pl.clf()

keras.utils.set_random_seed(123)
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=123)

class_colors = {0: "tab:blue", 1: "tab:orange", 2: "tab:green"}
validation_color = "lightgray"
class_names = ["Awake", "REM", "Non-REM"]

for i, (train_index, test_index) in enumerate(skf.split(model_input_data, output_data)):
  pl.figure(figsize=(4,4))

  # Plot train data
  pl.scatter(input_data[train_index][:,0], input_data[train_index][:,1], c=[class_colors[int(d)] for d in output_data[train_index]], s=100)
  pl.scatter(input_data[test_index][:,0], input_data[test_index][:,1], c=validation_color, s=100)
  pl.title(f'Split {i + 1}, validation fold in gray.')
  pl.show()

# %%
MODEL_CONFIG = {
  "input_dim": 50,
  "hidden_units": [32],
  "learning_rate": 0.1,
  "batch_size": 32,
  "epochs": 300,
  "early_stopping_patience": 15,
  "reduce_lr_patience": 5,
  "reduce_lr_factor": 0.5,
  "min_lr": 1e-5,
}

def create_model(config=MODEL_CONFIG):
  # Update MODEL_CONFIG here after cross-validation to reuse in partie 3
  mlp = keras.Sequential()
  mlp.add(layers.Input(shape=(config["input_dim"],)))

  for units in config["hidden_units"]:
      mlp.add(layers.Dense(units, activation="relu"))

  mlp.add(layers.Dense(3, activation="softmax"))

  mlp.compile(
      optimizer=keras.optimizers.Adam(learning_rate=config["learning_rate"]),
      loss="sparse_categorical_crossentropy",
      metrics=["accuracy"],
  )

  return mlp

mlp = create_model()
print("MODEL_CONFIG:", MODEL_CONFIG)
mlp.summary()
# Out:
# MODEL_CONFIG: {'input_dim': 50, 'hidden_units': [32], 'learning_rate': 0.1, 'batch_size': 32, 'epochs': 300, 'early_stopping_patience': 15, 'reduce_lr_patience': 5, 'reduce_lr_factor': 0.5, 'min_lr': 1e-05}
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 32)             │         1,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,731 (6.76 KB)
#  Trainable params: 1,731 (6.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_list = []
trained_mlp = []

from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=MODEL_CONFIG["early_stopping_patience"],
    min_delta=1e-4,
    restore_best_weights=True,
)
reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=MODEL_CONFIG["reduce_lr_factor"],
    patience=MODEL_CONFIG["reduce_lr_patience"],
    min_delta=1e-4,
    min_lr=MODEL_CONFIG["min_lr"],
    verbose=1,
)

for i, (train_index, test_index) in enumerate(skf.split(model_input_data, output_data)):
  # We need to create a new model every time otherwise fit will continue previous training
  mlp = create_model()

  class_values = np.unique(output_data[train_index])
  class_weights = compute_class_weight(class_weight="balanced", classes=class_values, y=output_data[train_index])
  class_weights = np.sqrt(class_weights)
  class_weights = class_weights / np.mean(class_weights)
  class_weight_dict = dict(zip(class_values, class_weights))

  history = mlp.fit(
      x=model_input_data[train_index],
      y=output_data[train_index],
      validation_data=(model_input_data[test_index], output_data[test_index]),
      epochs=MODEL_CONFIG["epochs"],
      batch_size=MODEL_CONFIG["batch_size"],
      class_weight=class_weight_dict,
      callbacks=[early_stopping, reduce_lr],
  )

  history_list.append(history)
  trained_mlp.append(mlp)
# Out:
# Epoch 1/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8168 - loss: 0.6665 - val_accuracy: 0.7853 - val_loss: 1.2583 - learning_rate: 0.1000
# Epoch 2/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8340 - loss: 0.4594 - val_accuracy: 0.8222 - val_loss: 1.0984 - learning_rate: 0.1000
# Epoch 3/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8417 - loss: 0.4605 - val_accuracy: 0.8211 - val_loss: 0.8035 - learning_rate: 0.1000
# Epoch 4/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8527 - loss: 0.4014 - val_accuracy: 0.8607 - val_loss: 0.5077 - learning_rate: 0.1000
# Epoch 5/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8613 - loss: 0.3867 - val_accuracy: 0.8151 - val_loss: 0.7016 - learning_rate: 0.1000
# Epoch 6/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8598 - loss: 0.4637 - val_accuracy: 0.8601 - val_loss: 0.6424 - learning_rate: 0.1000
# Epoch 7/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8561 - loss: 0.4562 - val_accuracy: 0.8394 - val_loss: 0.6199 - learning_rate: 0.1000
# Epoch 8/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8621 - loss: 0.4840 - val_accuracy: 0.8545 - val_loss: 0.6312 - learning_rate: 0.1000
# Epoch 9/300
# 833/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8640 - loss: 0.4070
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8663 - loss: 0.4084 - val_accuracy: 0.8626 - val_loss: 0.5952 - learning_rate: 0.1000
# Epoch 10/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8799 - loss: 0.2983 - val_accuracy: 0.8628 - val_loss: 0.4594 - learning_rate: 0.0500
# Epoch 11/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8832 - loss: 0.2873 - val_accuracy: 0.8561 - val_loss: 0.4519 - learning_rate: 0.0500
# Epoch 12/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8826 - loss: 0.2846 - val_accuracy: 0.8598 - val_loss: 0.4397 - learning_rate: 0.0500
# Epoch 13/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8814 - loss: 0.2863 - val_accuracy: 0.8547 - val_loss: 0.4495 - learning_rate: 0.0500
# Epoch 14/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8825 - loss: 0.2871 - val_accuracy: 0.8674 - val_loss: 0.4396 - learning_rate: 0.0500
# Epoch 15/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8819 - loss: 0.2892 - val_accuracy: 0.8589 - val_loss: 0.4650 - learning_rate: 0.0500
# Epoch 16/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8822 - loss: 0.2995 - val_accuracy: 0.8609 - val_loss: 0.4432 - learning_rate: 0.0500
# Epoch 17/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8810 - loss: 0.2986 - val_accuracy: 0.8658 - val_loss: 0.4355 - learning_rate: 0.0500
# Epoch 18/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8812 - loss: 0.2899 - val_accuracy: 0.8585 - val_loss: 0.4332 - learning_rate: 0.0500
# Epoch 19/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8806 - loss: 0.2921 - val_accuracy: 0.8647 - val_loss: 0.4235 - learning_rate: 0.0500
# Epoch 20/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8826 - loss: 0.2864 - val_accuracy: 0.8621 - val_loss: 0.4662 - learning_rate: 0.0500
# Epoch 21/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8818 - loss: 0.2849 - val_accuracy: 0.8702 - val_loss: 0.4454 - learning_rate: 0.0500
# Epoch 22/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8793 - loss: 0.2858 - val_accuracy: 0.8596 - val_loss: 0.4477 - learning_rate: 0.0500
# Epoch 23/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8811 - loss: 0.3057 - val_accuracy: 0.8598 - val_loss: 0.4951 - learning_rate: 0.0500
# Epoch 24/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8797 - loss: 0.3041
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8813 - loss: 0.2990 - val_accuracy: 0.8403 - val_loss: 0.4999 - learning_rate: 0.0500
# Epoch 25/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8869 - loss: 0.2590 - val_accuracy: 0.8806 - val_loss: 0.3801 - learning_rate: 0.0250
# Epoch 26/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8880 - loss: 0.2560 - val_accuracy: 0.8781 - val_loss: 0.3800 - learning_rate: 0.0250
# Epoch 27/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8882 - loss: 0.2549 - val_accuracy: 0.8801 - val_loss: 0.3756 - learning_rate: 0.0250
# Epoch 28/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8880 - loss: 0.2570 - val_accuracy: 0.8759 - val_loss: 0.3997 - learning_rate: 0.0250
# Epoch 29/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8884 - loss: 0.2622 - val_accuracy: 0.8737 - val_loss: 0.3822 - learning_rate: 0.0250
# Epoch 30/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8872 - loss: 0.2578 - val_accuracy: 0.8754 - val_loss: 0.3849 - learning_rate: 0.0250
# Epoch 31/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8881 - loss: 0.2534 - val_accuracy: 0.8790 - val_loss: 0.3797 - learning_rate: 0.0250
# Epoch 32/300
# 850/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8857 - loss: 0.2622
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8876 - loss: 0.2540 - val_accuracy: 0.8782 - val_loss: 0.3799 - learning_rate: 0.0250
# Epoch 33/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8912 - loss: 0.2434 - val_accuracy: 0.8851 - val_loss: 0.3522 - learning_rate: 0.0125
# Epoch 34/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8920 - loss: 0.2421 - val_accuracy: 0.8841 - val_loss: 0.3672 - learning_rate: 0.0125
# Epoch 35/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8922 - loss: 0.2428 - val_accuracy: 0.8842 - val_loss: 0.3682 - learning_rate: 0.0125
# Epoch 36/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8921 - loss: 0.2422 - val_accuracy: 0.8847 - val_loss: 0.3810 - learning_rate: 0.0125
# Epoch 37/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8918 - loss: 0.2420 - val_accuracy: 0.8847 - val_loss: 0.3652 - learning_rate: 0.0125
# Epoch 38/300
# 823/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8893 - loss: 0.2489
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8917 - loss: 0.2413 - val_accuracy: 0.8847 - val_loss: 0.3635 - learning_rate: 0.0125
# Epoch 39/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8938 - loss: 0.2357 - val_accuracy: 0.8888 - val_loss: 0.3464 - learning_rate: 0.0063
# Epoch 40/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8942 - loss: 0.2350 - val_accuracy: 0.8892 - val_loss: 0.3475 - learning_rate: 0.0063
# Epoch 41/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8939 - loss: 0.2351 - val_accuracy: 0.8895 - val_loss: 0.3456 - learning_rate: 0.0063
# Epoch 42/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8935 - loss: 0.2347 - val_accuracy: 0.8894 - val_loss: 0.3520 - learning_rate: 0.0063
# Epoch 43/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8933 - loss: 0.2346 - val_accuracy: 0.8897 - val_loss: 0.3527 - learning_rate: 0.0063
# Epoch 44/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8936 - loss: 0.2345 - val_accuracy: 0.8897 - val_loss: 0.3582 - learning_rate: 0.0063
# Epoch 45/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8936 - loss: 0.2344 - val_accuracy: 0.8897 - val_loss: 0.3568 - learning_rate: 0.0063
# Epoch 46/300
# 842/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8915 - loss: 0.2407
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8935 - loss: 0.2343 - val_accuracy: 0.8895 - val_loss: 0.3647 - learning_rate: 0.0063
# Epoch 47/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8935 - loss: 0.2319 - val_accuracy: 0.8908 - val_loss: 0.3606 - learning_rate: 0.0031
# Epoch 48/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8937 - loss: 0.2315 - val_accuracy: 0.8908 - val_loss: 0.3657 - learning_rate: 0.0031
# Epoch 49/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8941 - loss: 0.2314 - val_accuracy: 0.8907 - val_loss: 0.3668 - learning_rate: 0.0031
# Epoch 50/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8943 - loss: 0.2313 - val_accuracy: 0.8906 - val_loss: 0.3753 - learning_rate: 0.0031
# Epoch 51/300
# 815/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8920 - loss: 0.2380
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0015625000232830644.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8942 - loss: 0.2316 - val_accuracy: 0.8906 - val_loss: 0.3737 - learning_rate: 0.0031
# Epoch 52/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8944 - loss: 0.2300 - val_accuracy: 0.8896 - val_loss: 0.3808 - learning_rate: 0.0016
# Epoch 53/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8945 - loss: 0.2299 - val_accuracy: 0.8903 - val_loss: 0.3831 - learning_rate: 0.0016
# Epoch 54/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8945 - loss: 0.2298 - val_accuracy: 0.8904 - val_loss: 0.3880 - learning_rate: 0.0016
# Epoch 55/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8945 - loss: 0.2297 - val_accuracy: 0.8907 - val_loss: 0.3912 - learning_rate: 0.0016
# Epoch 56/300
# 844/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8932 - loss: 0.2355
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0007812500116415322.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8945 - loss: 0.2297 - val_accuracy: 0.8906 - val_loss: 0.3932 - learning_rate: 0.0016
# Epoch 1/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8318 - loss: 0.5658 - val_accuracy: 0.8449 - val_loss: 0.6198 - learning_rate: 0.1000
# Epoch 2/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8245 - loss: 0.4831 - val_accuracy: 0.8324 - val_loss: 0.5389 - learning_rate: 0.1000
# Epoch 3/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8351 - loss: 0.4134 - val_accuracy: 0.8146 - val_loss: 0.5447 - learning_rate: 0.1000
# Epoch 4/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8406 - loss: 0.3713 - val_accuracy: 0.8348 - val_loss: 0.5689 - learning_rate: 0.1000
# Epoch 5/300
# 832/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8377 - loss: 0.4546
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8403 - loss: 0.4511 - val_accuracy: 0.8361 - val_loss: 0.5707 - learning_rate: 0.1000
# Epoch 6/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8575 - loss: 0.3378 - val_accuracy: 0.8717 - val_loss: 0.3602 - learning_rate: 0.0500
# Epoch 7/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8727 - loss: 0.3066 - val_accuracy: 0.8790 - val_loss: 0.3520 - learning_rate: 0.0500
# Epoch 8/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8746 - loss: 0.2975 - val_accuracy: 0.8820 - val_loss: 0.3866 - learning_rate: 0.0500
# Epoch 9/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8747 - loss: 0.3058 - val_accuracy: 0.8821 - val_loss: 0.3531 - learning_rate: 0.0500
# Epoch 10/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8761 - loss: 0.2964 - val_accuracy: 0.8848 - val_loss: 0.3443 - learning_rate: 0.0500
# Epoch 11/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8775 - loss: 0.2937 - val_accuracy: 0.8852 - val_loss: 0.3454 - learning_rate: 0.0500
# Epoch 12/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8755 - loss: 0.3329 - val_accuracy: 0.8810 - val_loss: 0.3553 - learning_rate: 0.0500
# Epoch 13/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8770 - loss: 0.3091 - val_accuracy: 0.8864 - val_loss: 0.3531 - learning_rate: 0.0500
# Epoch 14/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8768 - loss: 0.2978 - val_accuracy: 0.8858 - val_loss: 0.3466 - learning_rate: 0.0500
# Epoch 15/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8744 - loss: 0.3042
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8758 - loss: 0.3161 - val_accuracy: 0.8805 - val_loss: 0.3537 - learning_rate: 0.0500
# Epoch 16/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8840 - loss: 0.2716 - val_accuracy: 0.8916 - val_loss: 0.3230 - learning_rate: 0.0250
# Epoch 17/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8852 - loss: 0.2660 - val_accuracy: 0.8915 - val_loss: 0.3215 - learning_rate: 0.0250
# Epoch 18/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8854 - loss: 0.2654 - val_accuracy: 0.8913 - val_loss: 0.3242 - learning_rate: 0.0250
# Epoch 19/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8854 - loss: 0.2656 - val_accuracy: 0.8925 - val_loss: 0.3257 - learning_rate: 0.0250
# Epoch 20/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8854 - loss: 0.2652 - val_accuracy: 0.8926 - val_loss: 0.3270 - learning_rate: 0.0250
# Epoch 21/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8858 - loss: 0.2666 - val_accuracy: 0.8927 - val_loss: 0.3278 - learning_rate: 0.0250
# Epoch 22/300
# 832/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8829 - loss: 0.2712
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8850 - loss: 0.2662 - val_accuracy: 0.8914 - val_loss: 0.3239 - learning_rate: 0.0250
# Epoch 23/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8885 - loss: 0.2540 - val_accuracy: 0.8921 - val_loss: 0.3122 - learning_rate: 0.0125
# Epoch 24/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8883 - loss: 0.2521 - val_accuracy: 0.8925 - val_loss: 0.3093 - learning_rate: 0.0125
# Epoch 25/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8890 - loss: 0.2512 - val_accuracy: 0.8923 - val_loss: 0.3093 - learning_rate: 0.0125
# Epoch 26/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8890 - loss: 0.2521 - val_accuracy: 0.8930 - val_loss: 0.3081 - learning_rate: 0.0125
# Epoch 27/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8883 - loss: 0.2510 - val_accuracy: 0.8925 - val_loss: 0.3091 - learning_rate: 0.0125
# Epoch 28/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8884 - loss: 0.2507 - val_accuracy: 0.8922 - val_loss: 0.3094 - learning_rate: 0.0125
# Epoch 29/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8884 - loss: 0.2511 - val_accuracy: 0.8924 - val_loss: 0.3096 - learning_rate: 0.0125
# Epoch 30/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8881 - loss: 0.2505 - val_accuracy: 0.8919 - val_loss: 0.3094 - learning_rate: 0.0125
# Epoch 31/300
# 834/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8876 - loss: 0.2558
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8883 - loss: 0.2507 - val_accuracy: 0.8918 - val_loss: 0.3097 - learning_rate: 0.0125
# Epoch 32/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8900 - loss: 0.2443 - val_accuracy: 0.8897 - val_loss: 0.3154 - learning_rate: 0.0063
# Epoch 33/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8900 - loss: 0.2433 - val_accuracy: 0.8908 - val_loss: 0.3152 - learning_rate: 0.0063
# Epoch 34/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8898 - loss: 0.2430 - val_accuracy: 0.8900 - val_loss: 0.3167 - learning_rate: 0.0063
# Epoch 35/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8897 - loss: 0.2429 - val_accuracy: 0.8905 - val_loss: 0.3168 - learning_rate: 0.0063
# Epoch 36/300
# 819/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8889 - loss: 0.2460
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8901 - loss: 0.2427 - val_accuracy: 0.8899 - val_loss: 0.3175 - learning_rate: 0.0063
# Epoch 37/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8917 - loss: 0.2393 - val_accuracy: 0.8912 - val_loss: 0.3151 - learning_rate: 0.0031
# Epoch 38/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8916 - loss: 0.2391 - val_accuracy: 0.8909 - val_loss: 0.3163 - learning_rate: 0.0031
# Epoch 39/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8917 - loss: 0.2387 - val_accuracy: 0.8913 - val_loss: 0.3178 - learning_rate: 0.0031
# Epoch 40/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8917 - loss: 0.2386 - val_accuracy: 0.8908 - val_loss: 0.3185 - learning_rate: 0.0031
# Epoch 41/300
# 843/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8899 - loss: 0.2413
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0015625000232830644.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8916 - loss: 0.2385 - val_accuracy: 0.8907 - val_loss: 0.3192 - learning_rate: 0.0031
# Epoch 1/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8254 - loss: 0.6106 - val_accuracy: 0.8402 - val_loss: 1.0190 - learning_rate: 0.1000
# Epoch 2/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8235 - loss: 0.4988 - val_accuracy: 0.8460 - val_loss: 0.5395 - learning_rate: 0.1000
# Epoch 3/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8437 - loss: 0.4011 - val_accuracy: 0.8518 - val_loss: 0.4510 - learning_rate: 0.1000
# Epoch 4/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8486 - loss: 0.4237 - val_accuracy: 0.8786 - val_loss: 0.4463 - learning_rate: 0.1000
# Epoch 5/300
# 849/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8600 - loss: 0.3829
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8591 - loss: 0.4005 - val_accuracy: 0.8740 - val_loss: 0.3935 - learning_rate: 0.1000
# Epoch 6/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8772 - loss: 0.2955 - val_accuracy: 0.8875 - val_loss: 0.3529 - learning_rate: 0.0500
# Epoch 7/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8792 - loss: 0.2959 - val_accuracy: 0.8883 - val_loss: 0.3295 - learning_rate: 0.0500
# Epoch 8/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8784 - loss: 0.2949 - val_accuracy: 0.8804 - val_loss: 0.3320 - learning_rate: 0.0500
# Epoch 9/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8776 - loss: 0.2904 - val_accuracy: 0.8829 - val_loss: 0.3297 - learning_rate: 0.0500
# Epoch 10/300
# 821/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8785 - loss: 0.2947
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8790 - loss: 0.2882 - val_accuracy: 0.8818 - val_loss: 0.3253 - learning_rate: 0.0500
# Epoch 11/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8864 - loss: 0.2644 - val_accuracy: 0.8903 - val_loss: 0.3081 - learning_rate: 0.0250
# Epoch 12/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8859 - loss: 0.2615 - val_accuracy: 0.8905 - val_loss: 0.3072 - learning_rate: 0.0250
# Epoch 13/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8866 - loss: 0.2607 - val_accuracy: 0.8920 - val_loss: 0.3071 - learning_rate: 0.0250
# Epoch 14/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8861 - loss: 0.2608 - val_accuracy: 0.8905 - val_loss: 0.3094 - learning_rate: 0.0250
# Epoch 15/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8858 - loss: 0.2616 - val_accuracy: 0.8919 - val_loss: 0.3059 - learning_rate: 0.0250
# Epoch 16/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8859 - loss: 0.2652 - val_accuracy: 0.8921 - val_loss: 0.3095 - learning_rate: 0.0250
# Epoch 17/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8862 - loss: 0.2607 - val_accuracy: 0.8926 - val_loss: 0.3091 - learning_rate: 0.0250
# Epoch 18/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8861 - loss: 0.2595 - val_accuracy: 0.8932 - val_loss: 0.3054 - learning_rate: 0.0250
# Epoch 19/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8860 - loss: 0.2624 - val_accuracy: 0.8927 - val_loss: 0.3151 - learning_rate: 0.0250
# Epoch 20/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8857 - loss: 0.2606 - val_accuracy: 0.8930 - val_loss: 0.3092 - learning_rate: 0.0250
# Epoch 21/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8861 - loss: 0.2567 - val_accuracy: 0.8941 - val_loss: 0.3040 - learning_rate: 0.0250
# Epoch 22/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8861 - loss: 0.2577 - val_accuracy: 0.8949 - val_loss: 0.3063 - learning_rate: 0.0250
# Epoch 23/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8858 - loss: 0.2584 - val_accuracy: 0.8955 - val_loss: 0.3165 - learning_rate: 0.0250
# Epoch 24/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8860 - loss: 0.2625 - val_accuracy: 0.8927 - val_loss: 0.3283 - learning_rate: 0.0250
# Epoch 25/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8861 - loss: 0.2556 - val_accuracy: 0.8950 - val_loss: 0.3088 - learning_rate: 0.0250
# Epoch 26/300
# 834/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8878 - loss: 0.2563
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8864 - loss: 0.2594 - val_accuracy: 0.8919 - val_loss: 0.3230 - learning_rate: 0.0250
# Epoch 27/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8909 - loss: 0.2460 - val_accuracy: 0.8976 - val_loss: 0.3025 - learning_rate: 0.0125
# Epoch 28/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8920 - loss: 0.2428 - val_accuracy: 0.8967 - val_loss: 0.3005 - learning_rate: 0.0125
# Epoch 29/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8917 - loss: 0.2414 - val_accuracy: 0.8972 - val_loss: 0.3031 - learning_rate: 0.0125
# Epoch 30/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8918 - loss: 0.2417 - val_accuracy: 0.8974 - val_loss: 0.3020 - learning_rate: 0.0125
# Epoch 31/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8919 - loss: 0.2416 - val_accuracy: 0.8971 - val_loss: 0.3064 - learning_rate: 0.0125
# Epoch 32/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8921 - loss: 0.2415 - val_accuracy: 0.8971 - val_loss: 0.3079 - learning_rate: 0.0125
# Epoch 33/300
# 847/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8914 - loss: 0.2421
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8919 - loss: 0.2402 - val_accuracy: 0.8975 - val_loss: 0.3047 - learning_rate: 0.0125
# Epoch 34/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8944 - loss: 0.2344 - val_accuracy: 0.8953 - val_loss: 0.3087 - learning_rate: 0.0063
# Epoch 35/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8946 - loss: 0.2326 - val_accuracy: 0.8955 - val_loss: 0.3092 - learning_rate: 0.0063
# Epoch 36/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8943 - loss: 0.2323 - val_accuracy: 0.8956 - val_loss: 0.3090 - learning_rate: 0.0063
# Epoch 37/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8950 - loss: 0.2313 - val_accuracy: 0.8950 - val_loss: 0.3144 - learning_rate: 0.0063
# Epoch 38/300
# 837/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8955 - loss: 0.2315
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8953 - loss: 0.2309 - val_accuracy: 0.8951 - val_loss: 0.3142 - learning_rate: 0.0063
# Epoch 39/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8961 - loss: 0.2280 - val_accuracy: 0.8933 - val_loss: 0.3224 - learning_rate: 0.0031
# Epoch 40/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8962 - loss: 0.2272 - val_accuracy: 0.8933 - val_loss: 0.3247 - learning_rate: 0.0031
# Epoch 41/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8966 - loss: 0.2266 - val_accuracy: 0.8934 - val_loss: 0.3295 - learning_rate: 0.0031
# Epoch 42/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8963 - loss: 0.2266 - val_accuracy: 0.8932 - val_loss: 0.3314 - learning_rate: 0.0031
# Epoch 43/300
# 835/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8965 - loss: 0.2266
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0015625000232830644.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8963 - loss: 0.2265 - val_accuracy: 0.8933 - val_loss: 0.3376 - learning_rate: 0.0031

# %% [markdown]
# # Plot training history

# %%
def pad_history_values(histories, key):
    max_len = max(len(history.history[key]) for history in histories)
    padded_values = np.full((len(histories), max_len), np.nan)
    for row_index, history in enumerate(histories):
        values = np.asarray(history.history[key], dtype=float)
        padded_values[row_index, :len(values)] = values
    return padded_values

train_losses = pad_history_values(history_list, 'loss')
val_losses = pad_history_values(history_list, 'val_loss')

# Calculate mean and standard deviation for training and validation losses
mean_train_loss = np.nanmean(train_losses, axis=0)
std_train_loss = np.nanstd(train_losses, axis=0)
mean_val_loss = np.nanmean(val_losses, axis=0)
std_val_loss = np.nanstd(val_losses, axis=0)

epochs = np.arange(1, len(mean_train_loss) + 1)

# Plot mean and standard deviation for training loss
pl.plot(epochs, mean_train_loss, label='Training Loss (Mean)')
pl.fill_between(epochs, mean_train_loss - std_train_loss, mean_train_loss + std_train_loss, alpha=0.3, label='Training Loss (Std)')

# Plot mean and standard deviation for validation loss
pl.plot(epochs, mean_val_loss, label='Validation Loss (Mean)')
pl.fill_between(epochs, mean_val_loss - std_val_loss, mean_val_loss + std_val_loss, alpha=0.3, label='Validation Loss (Std)')

# Add labels and legend
pl.xlabel('Epochs')
pl.ylabel('Loss')
pl.legend()

# Display the plot
pl.show()

# %% [markdown]
# # Performances

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, f1_score
import seaborn as sns

class_names = ["Awake", "REM", "Non-REM"]

def plot_confusion_matrix(confusion_matrix, title):
    # Plot confusion matrix
    pl.figure(figsize=(8, 6))
    sns.heatmap(confusion_matrix.astype(int), annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=class_names, yticklabels=class_names)
    pl.title(title)
    pl.xlabel('Predicted')
    pl.ylabel('True')
    pl.show()

f1_scores = []
mean_confusion_matrix = np.zeros((3, 3))

for i, (train_index, test_index) in enumerate(skf.split(model_input_data, output_data)):
    # Evaluate the trained model on the test fold
    predictions = np.argmax(trained_mlp[i].predict(model_input_data[test_index]), axis=1)
    true_labels = output_data[test_index]

    # Compute confusion matrix
    cm = confusion_matrix(true_labels, predictions, labels=[0, 1, 2])
    mean_confusion_matrix += cm

    # Compute confusion matrix and plot
    plot_confusion_matrix(cm, f'Confusion Matrix - Fold {i + 1}')

    # Compute F1 score
    f1 = f1_score(true_labels, predictions, average='micro')
    f1_scores.append(f1)
    print(f"F1 Score - Fold {i + 1}: {f1}")

# Plot mean confusion matrix
plot_confusion_matrix(mean_confusion_matrix, 'Global confusion matrix')

# Calculate and display the mean F1 score across all folds
mean_f1_score = np.mean(f1_scores)
print(f"Mean F1 Score across all folds: {mean_f1_score}")
# Out:
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# F1 Score - Fold 1: 0.8895088466338742
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# F1 Score - Fold 2: 0.8929594009250422
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# F1 Score - Fold 3: 0.8967036194112032
# Mean F1 Score across all folds: 0.89305728899004

# %% [markdown]
# # Exercise
#
# Please try changing hyperparameters (number of neurons, number of layers, learning rate, momentum, number of epochs...) and observe the impact it has on training and validation loss, convergence, and computation time. For instance, observe if there's overfitting if you put a high number (i.e. 128) of neurons in the hidden layer.
#
# You can also experiment with different datasets (clear separation between classes, unbalanced...)
