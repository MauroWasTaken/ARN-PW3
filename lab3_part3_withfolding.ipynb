# %% [markdown]
# # Practical Work 3

# %% [markdown]
# ## Loading the packages

# %%
import numpy as np
import matplotlib.pyplot as pl ## hello

# %% [markdown]
# ## The Dataset

# %%
# %pip install ipympl
# Out:
# /home/yomaru/HEIG/arn/ARN-PW3/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

 # Change this to any folder where data is if needed
mouse1 = pd.read_csv('EEG_mouse_data_1.csv')
mouse2 = pd.read_csv('EEG_mouse_data_2.csv')
dataset = pd.concat([mouse1, mouse2])
dataset
# Out:
#       state  amplitude_around_1_Hertz  amplitude_around_2_Hertz  \
# 0         n                  0.000009                  0.000014
# 1         n                  0.000010                  0.000010
# 2         n                  0.000011                  0.000077
# 3         w                  0.000003                  0.000031
# 4         w                  0.000010                  0.000011
# ...     ...                       ...                       ...
# 20600     w                  0.000025                  0.000007
# 20601     w                  0.000017                  0.000038
# 20602     w                  0.000016                  0.000028
# 20603     w                  0.000013                  0.000014
# 20604     w                  0.000004                  0.000006
#
#        amplitude_around_3_Hertz  amplitude_around_4_Hertz  \
# 0                      0.000013                  0.000014
# 1                      0.000011                  0.000015
# 2                      0.000034                  0.000019
# 3                      0.000044                  0.000016
# 4                      0.000012                  0.000017
# ...                         ...                       ...
# 20600                  0.000007                  0.000003
# 20601                  0.000015                  0.000011
# 20602                  0.000031                  0.000011
# 20603                  0.000020                  0.000018
# 20604                  0.000011                  0.000025
#
#        amplitude_around_5_Hertz  amplitude_around_6_Hertz  \
# 0                      0.000023                  0.000009
# 1                      0.000022                  0.000017
# 2                      0.000013                  0.000006
# 3                      0.000007                  0.000006
# 4                      0.000020                  0.000018
# ...                         ...                       ...
# 20600                  0.000005                  0.000002
# 20601                  0.000019                  0.000006
# 20602                  0.000019                  0.000001
# 20603                  0.000007                  0.000013
# 20604                  0.000040                  0.000007
#
#        amplitude_around_7_Hertz  amplitude_around_8_Hertz  \
# 0                      0.000019                  0.000011
# 1                      0.000027                  0.000011
# 2                      0.000010                  0.000004
# 3                      0.000005                  0.000007
# 4                      0.000014                  0.000025
# ...                         ...                       ...
# 20600                  0.000005                  0.000010
# 20601                  0.000010                  0.000012
# 20602                  0.000015                  0.000002
# 20603                  0.000009                  0.000018
# 20604                  0.000005                  0.000021
#
#        amplitude_around_9_Hertz  ...  amplitude_around_92_Hertz  \
# 0                      0.000016  ...               8.364060e-09
# 1                      0.000011  ...               6.695745e-09
# 2                      0.000006  ...               1.105705e-08
# 3                      0.000006  ...               2.223992e-08
# 4                      0.000018  ...               6.541705e-09
# ...                         ...  ...                        ...
# 20600                  0.000013  ...               1.162051e-08
# 20601                  0.000009  ...               1.456810e-08
# 20602                  0.000007  ...               1.197483e-08
# 20603                  0.000005  ...               3.028127e-08
# 20604                  0.000011  ...               1.434414e-08
#
#        amplitude_around_93_Hertz  amplitude_around_94_Hertz  \
# 0                   4.208368e-09               2.177679e-09
# 1                   1.213822e-08               2.287185e-08
# 2                   3.264479e-09               1.204057e-09
# 3                   1.028462e-08               3.561479e-09
# 4                   3.312024e-09               8.779863e-09
# ...                          ...                        ...
# 20600               9.470367e-09               1.542617e-08
# 20601               9.259630e-09               3.831858e-08
# 20602               2.496412e-08               2.292325e-08
# 20603               9.760537e-09               3.475243e-09
# 20604               1.081698e-08               6.120670e-09
#
#        amplitude_around_95_Hertz  amplitude_around_96_Hertz  \
# 0                   4.342505e-09               5.130010e-09
# 1                   3.219380e-09               2.461736e-09
# 2                   5.090074e-09               5.477467e-09
# 3                   3.704753e-09               2.425319e-09
# 4                   7.400000e-09               2.890853e-09
# ...                          ...                        ...
# 20600               6.114029e-09               2.346950e-09
# 20601               3.839020e-09               4.668449e-09
# 20602               2.783310e-09               6.423075e-09
# 20603               2.667755e-09               4.243288e-09
# 20604               4.113743e-09               6.910015e-09
#
#        amplitude_around_97_Hertz  amplitude_around_98_Hertz  \
# 0                   2.852361e-09               9.772395e-10
# 1                   2.985953e-09               1.434412e-09
# 2                   1.809223e-09               7.064289e-10
# 3                   1.536834e-09               2.540238e-10
# 4                   5.709757e-10               2.171227e-09
# ...                          ...                        ...
# 20600               4.264138e-09               1.733832e-09
# 20601               1.671207e-09               2.347928e-09
# 20602               3.649511e-09               4.350072e-09
# 20603               6.048632e-09               3.234623e-09
# 20604               7.412423e-09               3.527602e-09
#
#        amplitude_around_99_Hertz  amplitude_around_100_Hertz  \
# 0                   1.876307e-09                5.457793e-09
# 1                   1.579590e-09                5.458902e-09
# 2                   1.435585e-09                7.416121e-09
# 3                   6.300358e-10                3.647454e-09
# 4                   6.757242e-10                2.005702e-09
# ...                          ...                         ...
# 20600               8.314190e-10                1.720087e-09
# 20601               2.219437e-09                2.045267e-09
# 20602               6.656486e-10                2.086456e-09
# 20603               1.421633e-09                9.709723e-10
# 20604               2.895608e-09                4.211010e-09
#
#        amplitude_around_101_Hertz
# 0                    8.653900e-08
# 1                    8.492570e-08
# 2                    1.156240e-07
# 3                    2.212800e-08
# 4                    2.861980e-10
# ...                           ...
# 20600                1.345590e-09
# 20601                6.063210e-09
# 20602                2.761580e-08
# 20603                2.062290e-08
# 20604                3.054510e-08
#
# [40863 rows x 102 columns]

# %% [markdown]
# <font color="red">**For it to work on Colab, you will need to reload your session (Exécution -> redémarrer la session)**</font>

# %% [markdown]
# <font color="orange">**Make sure to put a large amount of points otherwise the cross validation folds will be really small**</font>

# %% [markdown]
# ## Show the dataset

# %%
dataset = np.array(dataset)
dataset
# Out:
# array([['n', 9.123150377376987e-06, 1.3656147984875132e-05, ...,
#         1.8763067211047253e-09, 5.457792863483579e-09,
#         8.653900351873746e-08],
#        ['n', 9.79506089393567e-06, 9.573940179308238e-06, ...,
#         1.5795897784220971e-09, 5.4589015668904395e-09,
#         8.492570202633942e-08],
#        ['n', 1.0809589923610474e-05, 7.670862305531045e-05, ...,
#         1.435585247899773e-09, 7.4161209742684706e-09,
#         1.1562399748754617e-07],
#        ...,
#        ['w', 1.6213877302106994e-05, 2.8464069458777885e-05, ...,
#         6.656486386397154e-10, 2.08645636011473e-09,
#         2.7615799425007026e-08],
#        ['w', 1.2860698049621533e-05, 1.3600040119854384e-05, ...,
#         1.421632783715765e-09, 9.70972280009419e-10,
#         2.062290072046835e-08],
#        ['w', 3.5420524397977715e-06, 5.874647627024388e-06, ...,
#         2.8956081976616584e-09, 4.211009985155556e-09,
#         3.054509889466317e-08]], shape=(40863, 102), dtype=object)

# %%
input_data = dataset[:, 1:11].astype(float)
input_data = (input_data - input_data.mean(axis=0)) / (input_data.std(axis=0) + 1e-8)  # Standardize each feature
state_to_class = {"w": 0, "r": 1, "n": 2}
output_data = np.array([state_to_class[state] for state in dataset[:, 0]], dtype=int)

temporal_window = 4

def make_past_context_features(X, window=4):
    # Builds [x(t-window), ..., x(t-1), x(t)] for each sample at time t
    n, d = X.shape
    context_parts = []
    for lag in range(window, 0, -1):
        shifted = np.empty_like(X)
        shifted[:lag] = X[0]
        shifted[lag:] = X[:-lag]
        context_parts.append(shifted)
    context_parts.append(X)
    return np.hstack(context_parts)

model_input_data = make_past_context_features(input_data, window=temporal_window)

# %%
input_data
# Out:
# array([[-0.20987265, -0.08194901, -0.1050478 , ..., -0.12720215,
#          0.70849675,  1.30767881],
#        [-0.1833618 , -0.32559618, -0.23035843, ..., -0.1001689 ,
#          0.09924395,  0.25545035],
#        [-0.14333261,  3.68134731,  1.38922012, ..., -0.7483781 ,
#         -0.45690898, -0.72108948],
#        ...,
#        [ 0.06989857,  0.80186398,  1.18418179, ..., -0.92162007,
#         -0.29742897, -0.90504528],
#        [-0.06240423, -0.08529781,  0.37567232, ...,  0.54767347,
#         -0.59646021, -0.69274525],
#        [-0.43008006, -0.54638901, -0.24674486, ...,  0.81216587,
#          0.09678055,  0.04914934]], shape=(40863, 10))

# %%
output_data
# Out:
# array([2, 2, 2, ..., 0, 0, 0], shape=(40863,))

# %%
# Check data balance
class_names = ["Awake", "REM", "Non-REM"]
unique, counts = np.unique(output_data, return_counts=True)
for label, count in zip(unique, counts):
    state = class_names[label]
    print(f"{state}: {count} samples ({count/len(output_data)*100:.1f}%)")
# Out:
# Awake: 24360 samples (59.6%)
# REM: 2839 samples (6.9%)
# Non-REM: 13664 samples (33.4%)

# %%
# %matplotlib inline

# %%
import keras
from keras import layers
from sklearn.model_selection import StratifiedKFold

pl.clf()

keras.utils.set_random_seed(123)
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=123)

class_colors = {0: "tab:blue", 1: "tab:orange", 2: "tab:green"}
validation_color = "lightgray"
class_names = ["Awake", "REM", "Non-REM"]

for i, (train_index, test_index) in enumerate(skf.split(model_input_data, output_data)):
  pl.figure(figsize=(4,4))

  # Plot train data
  pl.scatter(input_data[train_index][:,0], input_data[train_index][:,1], c=[class_colors[int(d)] for d in output_data[train_index]], s=100)
  pl.scatter(input_data[test_index][:,0], input_data[test_index][:,1], c=validation_color, s=100)
  pl.title(f'Split {i + 1}, validation fold in gray.')
  pl.show()

# %%
MODEL_CONFIG = {
  "input_dim": 50,
  "hidden_units": [32],
  "learning_rate": 0.1,
  "batch_size": 32,
  "epochs": 300,
  "early_stopping_patience": 15,
  "reduce_lr_patience": 5,
  "reduce_lr_factor": 0.5,
  "min_lr": 1e-5,
}

def create_model(config=MODEL_CONFIG):
  # Update MODEL_CONFIG here after cross-validation to reuse in partie 3
  mlp = keras.Sequential()
  mlp.add(layers.Input(shape=(config["input_dim"],)))

  for units in config["hidden_units"]:
      mlp.add(layers.Dense(units, activation="relu"))

  mlp.add(layers.Dense(3, activation="softmax"))

  mlp.compile(
      optimizer=keras.optimizers.SGD(learning_rate=config["learning_rate"], momentum=0.8),
      loss="sparse_categorical_crossentropy",
      metrics=["accuracy"],
  )

  return mlp

mlp = create_model()
print("MODEL_CONFIG:", MODEL_CONFIG)
mlp.summary()
# Out:
# MODEL_CONFIG: {'input_dim': 50, 'hidden_units': [32], 'learning_rate': 0.1, 'batch_size': 32, 'epochs': 300, 'early_stopping_patience': 15, 'reduce_lr_patience': 5, 'reduce_lr_factor': 0.5, 'min_lr': 1e-05}
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 32)             │         1,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,731 (6.76 KB)
#  Trainable params: 1,731 (6.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_list = []
trained_mlp = []

from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=MODEL_CONFIG["early_stopping_patience"],
    min_delta=1e-4,
    restore_best_weights=True,
)
reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=MODEL_CONFIG["reduce_lr_factor"],
    patience=MODEL_CONFIG["reduce_lr_patience"],
    min_delta=1e-4,
    min_lr=MODEL_CONFIG["min_lr"],
    verbose=1,
)

for i, (train_index, test_index) in enumerate(skf.split(model_input_data, output_data)):
  # We need to create a new model every time otherwise fit will continue previous training
  mlp = create_model()

  class_values = np.unique(output_data[train_index])
  class_weights = compute_class_weight(class_weight="balanced", classes=class_values, y=output_data[train_index])
  class_weights = np.sqrt(class_weights)
  class_weights = class_weights / np.mean(class_weights)
  class_weight_dict = dict(zip(class_values, class_weights))

  history = mlp.fit(
      x=model_input_data[train_index],
      y=output_data[train_index],
      validation_data=(model_input_data[test_index], output_data[test_index]),
      epochs=MODEL_CONFIG["epochs"],
      batch_size=MODEL_CONFIG["batch_size"],
      class_weight=class_weight_dict,
      callbacks=[early_stopping, reduce_lr],
  )

  history_list.append(history)
  trained_mlp.append(mlp)
# Out:
# Epoch 1/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8780 - loss: 0.2698 - val_accuracy: 0.8832 - val_loss: 0.3764 - learning_rate: 0.1000
# Epoch 2/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8889 - loss: 0.2549 - val_accuracy: 0.8685 - val_loss: 0.3919 - learning_rate: 0.1000
# Epoch 3/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8919 - loss: 0.2604 - val_accuracy: 0.8779 - val_loss: 0.3918 - learning_rate: 0.1000
# Epoch 4/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8892 - loss: 0.2691 - val_accuracy: 0.8643 - val_loss: 0.4287 - learning_rate: 0.1000
# Epoch 5/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8931 - loss: 0.2448 - val_accuracy: 0.8904 - val_loss: 0.3290 - learning_rate: 0.1000
# Epoch 6/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8954 - loss: 0.2351 - val_accuracy: 0.8815 - val_loss: 0.3618 - learning_rate: 0.1000
# Epoch 7/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8984 - loss: 0.2305 - val_accuracy: 0.8911 - val_loss: 0.3234 - learning_rate: 0.1000
# Epoch 8/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8997 - loss: 0.2221 - val_accuracy: 0.8930 - val_loss: 0.3094 - learning_rate: 0.1000
# Epoch 9/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9001 - loss: 0.2254 - val_accuracy: 0.8897 - val_loss: 0.3382 - learning_rate: 0.1000
# Epoch 10/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8978 - loss: 0.2308 - val_accuracy: 0.8728 - val_loss: 0.3942 - learning_rate: 0.1000
# Epoch 11/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9013 - loss: 0.2214 - val_accuracy: 0.8827 - val_loss: 0.3429 - learning_rate: 0.1000
# Epoch 12/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9025 - loss: 0.2170 - val_accuracy: 0.8905 - val_loss: 0.3215 - learning_rate: 0.1000
# Epoch 13/300
# 836/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9046 - loss: 0.2127
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9046 - loss: 0.2115 - val_accuracy: 0.8882 - val_loss: 0.3389 - learning_rate: 0.1000
# Epoch 14/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9107 - loss: 0.1956 - val_accuracy: 0.8916 - val_loss: 0.3592 - learning_rate: 0.0500
# Epoch 15/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9118 - loss: 0.1894 - val_accuracy: 0.8955 - val_loss: 0.3012 - learning_rate: 0.0500
# Epoch 16/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9146 - loss: 0.1815 - val_accuracy: 0.8982 - val_loss: 0.2989 - learning_rate: 0.0500
# Epoch 17/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9161 - loss: 0.1782 - val_accuracy: 0.8979 - val_loss: 0.2987 - learning_rate: 0.0500
# Epoch 18/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9165 - loss: 0.1795 - val_accuracy: 0.8969 - val_loss: 0.2995 - learning_rate: 0.0500
# Epoch 19/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9171 - loss: 0.1766 - val_accuracy: 0.8966 - val_loss: 0.2996 - learning_rate: 0.0500
# Epoch 20/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9182 - loss: 0.1744 - val_accuracy: 0.8959 - val_loss: 0.3041 - learning_rate: 0.0500
# Epoch 21/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9172 - loss: 0.1776 - val_accuracy: 0.8977 - val_loss: 0.3009 - learning_rate: 0.0500
# Epoch 22/300
# 842/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9172 - loss: 0.1779
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9181 - loss: 0.1753 - val_accuracy: 0.8974 - val_loss: 0.3098 - learning_rate: 0.0500
# Epoch 23/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9232 - loss: 0.1658 - val_accuracy: 0.8993 - val_loss: 0.2970 - learning_rate: 0.0250
# Epoch 24/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9240 - loss: 0.1612 - val_accuracy: 0.8992 - val_loss: 0.2989 - learning_rate: 0.0250
# Epoch 25/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9242 - loss: 0.1602 - val_accuracy: 0.8992 - val_loss: 0.3000 - learning_rate: 0.0250
# Epoch 26/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9242 - loss: 0.1591 - val_accuracy: 0.8988 - val_loss: 0.3014 - learning_rate: 0.0250
# Epoch 27/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9243 - loss: 0.1576 - val_accuracy: 0.8982 - val_loss: 0.3033 - learning_rate: 0.0250
# Epoch 28/300
# 824/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9232 - loss: 0.1629
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9243 - loss: 0.1573 - val_accuracy: 0.8985 - val_loss: 0.3040 - learning_rate: 0.0250
# Epoch 29/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9265 - loss: 0.1522 - val_accuracy: 0.8967 - val_loss: 0.3093 - learning_rate: 0.0125
# Epoch 30/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9262 - loss: 0.1509 - val_accuracy: 0.8965 - val_loss: 0.3100 - learning_rate: 0.0125
# Epoch 31/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9263 - loss: 0.1504 - val_accuracy: 0.8968 - val_loss: 0.3103 - learning_rate: 0.0125
# Epoch 32/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9266 - loss: 0.1500 - val_accuracy: 0.8968 - val_loss: 0.3110 - learning_rate: 0.0125
# Epoch 33/300
# 851/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9260 - loss: 0.1549
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9268 - loss: 0.1496 - val_accuracy: 0.8963 - val_loss: 0.3111 - learning_rate: 0.0125
# Epoch 34/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9289 - loss: 0.1471 - val_accuracy: 0.8956 - val_loss: 0.3136 - learning_rate: 0.0063
# Epoch 35/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9290 - loss: 0.1464 - val_accuracy: 0.8956 - val_loss: 0.3139 - learning_rate: 0.0063
# Epoch 36/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9286 - loss: 0.1461 - val_accuracy: 0.8960 - val_loss: 0.3141 - learning_rate: 0.0063
# Epoch 37/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9288 - loss: 0.1459 - val_accuracy: 0.8959 - val_loss: 0.3144 - learning_rate: 0.0063
# Epoch 38/300
# 846/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9269 - loss: 0.1508
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9291 - loss: 0.1457 - val_accuracy: 0.8966 - val_loss: 0.3147 - learning_rate: 0.0063
# Epoch 1/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8763 - loss: 0.2702 - val_accuracy: 0.8943 - val_loss: 0.2842 - learning_rate: 0.1000
# Epoch 2/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8920 - loss: 0.2374 - val_accuracy: 0.8952 - val_loss: 0.2836 - learning_rate: 0.1000
# Epoch 3/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8951 - loss: 0.2308 - val_accuracy: 0.8953 - val_loss: 0.2889 - learning_rate: 0.1000
# Epoch 4/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8933 - loss: 0.2398 - val_accuracy: 0.8921 - val_loss: 0.2955 - learning_rate: 0.1000
# Epoch 5/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8969 - loss: 0.2244 - val_accuracy: 0.8937 - val_loss: 0.2954 - learning_rate: 0.1000
# Epoch 6/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9009 - loss: 0.2190 - val_accuracy: 0.8957 - val_loss: 0.2888 - learning_rate: 0.1000
# Epoch 7/300
# 819/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9017 - loss: 0.2204
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9011 - loss: 0.2219 - val_accuracy: 0.8985 - val_loss: 0.2875 - learning_rate: 0.1000
# Epoch 8/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9087 - loss: 0.2018 - val_accuracy: 0.9012 - val_loss: 0.2743 - learning_rate: 0.0500
# Epoch 9/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9118 - loss: 0.1927 - val_accuracy: 0.9015 - val_loss: 0.2751 - learning_rate: 0.0500
# Epoch 10/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9119 - loss: 0.1956 - val_accuracy: 0.9015 - val_loss: 0.2755 - learning_rate: 0.0500
# Epoch 11/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9126 - loss: 0.1897 - val_accuracy: 0.9024 - val_loss: 0.2733 - learning_rate: 0.0500
# Epoch 12/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9120 - loss: 0.1909 - val_accuracy: 0.9020 - val_loss: 0.2748 - learning_rate: 0.0500
# Epoch 13/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9137 - loss: 0.1862 - val_accuracy: 0.9040 - val_loss: 0.2704 - learning_rate: 0.0500
# Epoch 14/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9137 - loss: 0.1856 - val_accuracy: 0.9031 - val_loss: 0.2705 - learning_rate: 0.0500
# Epoch 15/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9143 - loss: 0.1838 - val_accuracy: 0.9030 - val_loss: 0.2719 - learning_rate: 0.0500
# Epoch 16/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9152 - loss: 0.1822 - val_accuracy: 0.9033 - val_loss: 0.2735 - learning_rate: 0.0500
# Epoch 17/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9132 - loss: 0.1884 - val_accuracy: 0.8993 - val_loss: 0.2772 - learning_rate: 0.0500
# Epoch 18/300
# 816/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9137 - loss: 0.1866
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9140 - loss: 0.1839 - val_accuracy: 0.9011 - val_loss: 0.2756 - learning_rate: 0.0500
# Epoch 19/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9197 - loss: 0.1730 - val_accuracy: 0.9039 - val_loss: 0.2752 - learning_rate: 0.0250
# Epoch 20/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9217 - loss: 0.1661 - val_accuracy: 0.9041 - val_loss: 0.2763 - learning_rate: 0.0250
# Epoch 21/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9216 - loss: 0.1694 - val_accuracy: 0.9034 - val_loss: 0.2779 - learning_rate: 0.0250
# Epoch 22/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9225 - loss: 0.1643 - val_accuracy: 0.9027 - val_loss: 0.2793 - learning_rate: 0.0250
# Epoch 23/300
# 814/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9202 - loss: 0.1753
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9216 - loss: 0.1680 - val_accuracy: 0.9023 - val_loss: 0.2795 - learning_rate: 0.0250
# Epoch 24/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9239 - loss: 0.1588 - val_accuracy: 0.9025 - val_loss: 0.2801 - learning_rate: 0.0125
# Epoch 25/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9248 - loss: 0.1587 - val_accuracy: 0.9018 - val_loss: 0.2808 - learning_rate: 0.0125
# Epoch 26/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9255 - loss: 0.1568 - val_accuracy: 0.9018 - val_loss: 0.2815 - learning_rate: 0.0125
# Epoch 27/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9250 - loss: 0.1574 - val_accuracy: 0.9010 - val_loss: 0.2825 - learning_rate: 0.0125
# Epoch 28/300
# 839/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9244 - loss: 0.1609
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9256 - loss: 0.1559 - val_accuracy: 0.9015 - val_loss: 0.2834 - learning_rate: 0.0125
# Epoch 1/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8799 - loss: 0.2641 - val_accuracy: 0.8948 - val_loss: 0.2959 - learning_rate: 0.1000
# Epoch 2/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8902 - loss: 0.2503 - val_accuracy: 0.8960 - val_loss: 0.3060 - learning_rate: 0.1000
# Epoch 3/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8974 - loss: 0.2321 - val_accuracy: 0.9038 - val_loss: 0.2853 - learning_rate: 0.1000
# Epoch 4/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8985 - loss: 0.2265 - val_accuracy: 0.9036 - val_loss: 0.2719 - learning_rate: 0.1000
# Epoch 5/300
# 824/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8995 - loss: 0.2204
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9005 - loss: 0.2193 - val_accuracy: 0.8981 - val_loss: 0.3019 - learning_rate: 0.1000
# Epoch 6/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9074 - loss: 0.2057 - val_accuracy: 0.9046 - val_loss: 0.2654 - learning_rate: 0.0500
# Epoch 7/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9097 - loss: 0.1941 - val_accuracy: 0.8943 - val_loss: 0.3317 - learning_rate: 0.0500
# Epoch 8/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9100 - loss: 0.1935 - val_accuracy: 0.9060 - val_loss: 0.2631 - learning_rate: 0.0500
# Epoch 9/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9116 - loss: 0.1879 - val_accuracy: 0.9059 - val_loss: 0.2669 - learning_rate: 0.0500
# Epoch 10/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9116 - loss: 0.1868 - val_accuracy: 0.9065 - val_loss: 0.2652 - learning_rate: 0.0500
# Epoch 11/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9128 - loss: 0.1838 - val_accuracy: 0.9050 - val_loss: 0.2668 - learning_rate: 0.0500
# Epoch 12/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9134 - loss: 0.1834 - val_accuracy: 0.9038 - val_loss: 0.2698 - learning_rate: 0.0500
# Epoch 13/300
# 826/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9148 - loss: 0.1799
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9137 - loss: 0.1814 - val_accuracy: 0.9028 - val_loss: 0.2701 - learning_rate: 0.0500
# Epoch 14/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9174 - loss: 0.1750 - val_accuracy: 0.8965 - val_loss: 0.2911 - learning_rate: 0.0250
# Epoch 15/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9182 - loss: 0.1721 - val_accuracy: 0.8986 - val_loss: 0.2756 - learning_rate: 0.0250
# Epoch 16/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9192 - loss: 0.1690 - val_accuracy: 0.8955 - val_loss: 0.2918 - learning_rate: 0.0250
# Epoch 17/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9188 - loss: 0.1696 - val_accuracy: 0.8975 - val_loss: 0.2801 - learning_rate: 0.0250
# Epoch 18/300
# 821/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9210 - loss: 0.1629
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9195 - loss: 0.1661 - val_accuracy: 0.8978 - val_loss: 0.2791 - learning_rate: 0.0250
# Epoch 19/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9228 - loss: 0.1598 - val_accuracy: 0.8967 - val_loss: 0.2900 - learning_rate: 0.0125
# Epoch 20/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9237 - loss: 0.1588 - val_accuracy: 0.8976 - val_loss: 0.2808 - learning_rate: 0.0125
# Epoch 21/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9238 - loss: 0.1578 - val_accuracy: 0.8949 - val_loss: 0.2924 - learning_rate: 0.0125
# Epoch 22/300
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9235 - loss: 0.1581 - val_accuracy: 0.8975 - val_loss: 0.2819 - learning_rate: 0.0125
# Epoch 23/300
# 816/852 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9256 - loss: 0.1538
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9242 - loss: 0.1569 - val_accuracy: 0.8966 - val_loss: 0.2826 - learning_rate: 0.0125

# %% [markdown]
# # Plot training history

# %%
def pad_history_values(histories, key):
    max_len = max(len(history.history[key]) for history in histories)
    padded_values = np.full((len(histories), max_len), np.nan)
    for row_index, history in enumerate(histories):
        values = np.asarray(history.history[key], dtype=float)
        padded_values[row_index, :len(values)] = values
    return padded_values

train_losses = pad_history_values(history_list, 'loss')
val_losses = pad_history_values(history_list, 'val_loss')

# Calculate mean and standard deviation for training and validation losses
mean_train_loss = np.nanmean(train_losses, axis=0)
std_train_loss = np.nanstd(train_losses, axis=0)
mean_val_loss = np.nanmean(val_losses, axis=0)
std_val_loss = np.nanstd(val_losses, axis=0)

epochs = np.arange(1, len(mean_train_loss) + 1)

# Plot mean and standard deviation for training loss
pl.plot(epochs, mean_train_loss, label='Training Loss (Mean)')
pl.fill_between(epochs, mean_train_loss - std_train_loss, mean_train_loss + std_train_loss, alpha=0.3, label='Training Loss (Std)')

# Plot mean and standard deviation for validation loss
pl.plot(epochs, mean_val_loss, label='Validation Loss (Mean)')
pl.fill_between(epochs, mean_val_loss - std_val_loss, mean_val_loss + std_val_loss, alpha=0.3, label='Validation Loss (Std)')

# Add labels and legend
pl.xlabel('Epochs')
pl.ylabel('Loss')
pl.legend()

# Display the plot
pl.show()

# %% [markdown]
# # Performances

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, f1_score
import seaborn as sns

class_names = ["Awake", "REM", "Non-REM"]

def plot_confusion_matrix(confusion_matrix, title):
    # Plot confusion matrix
    pl.figure(figsize=(8, 6))
    sns.heatmap(confusion_matrix.astype(int), annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=class_names, yticklabels=class_names)
    pl.title(title)
    pl.xlabel('Predicted')
    pl.ylabel('True')
    pl.show()

f1_scores = []
mean_confusion_matrix = np.zeros((3, 3))

for i, (train_index, test_index) in enumerate(skf.split(model_input_data, output_data)):
    # Evaluate the trained model on the test fold
    predictions = np.argmax(trained_mlp[i].predict(model_input_data[test_index]), axis=1)
    true_labels = output_data[test_index]

    # Compute confusion matrix
    cm = confusion_matrix(true_labels, predictions, labels=[0, 1, 2])
    mean_confusion_matrix += cm

    # Compute confusion matrix and plot
    plot_confusion_matrix(cm, f'Confusion Matrix - Fold {i + 1}')

    # Compute F1 score
    f1 = f1_score(true_labels, predictions, average='micro')
    f1_scores.append(f1)
    print(f"F1 Score - Fold {i + 1}: {f1}")

# Plot mean confusion matrix
plot_confusion_matrix(mean_confusion_matrix, 'Global confusion matrix')

# Calculate and display the mean F1 score across all folds
mean_f1_score = np.mean(f1_scores)
print(f"Mean F1 Score across all folds: {mean_f1_score}")
# Out:
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step
# F1 Score - Fold 1: 0.8992731811173923
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# F1 Score - Fold 2: 0.904045224286029
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# F1 Score - Fold 3: 0.9059540415534836
# Mean F1 Score across all folds: 0.9030908156523015

# %% [markdown]
# # Exercise
#
# Please try changing hyperparameters (number of neurons, number of layers, learning rate, momentum, number of epochs...) and observe the impact it has on training and validation loss, convergence, and computation time. For instance, observe if there's overfitting if you put a high number (i.e. 128) of neurons in the hidden layer.
#
# You can also experiment with different datasets (clear separation between classes, unbalanced...)
