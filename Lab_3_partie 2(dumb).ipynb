# %% [markdown]
# # Practical Work 3

# %% [markdown]
# ## Loading the packages

# %%
import numpy as np
import matplotlib.pyplot as pl ## hello

# %% [markdown]
# ## The Dataset

# %%
# %pip install ipympl
# Out:
# /home/yomaru/HEIG/arn/ARN-PW3/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

 # Change this to any folder where data is if needed
mouse1 = pd.read_csv('EEG_mouse_data_1.csv')
mouse2 = pd.read_csv('EEG_mouse_data_2.csv')
dataset = pd.concat([mouse1, mouse2])
dataset
# Out:
#       state  amplitude_around_1_Hertz  amplitude_around_2_Hertz  \
# 0         n                  0.000009                  0.000014
# 1         n                  0.000010                  0.000010
# 2         n                  0.000011                  0.000077
# 3         w                  0.000003                  0.000031
# 4         w                  0.000010                  0.000011
# ...     ...                       ...                       ...
# 20600     w                  0.000025                  0.000007
# 20601     w                  0.000017                  0.000038
# 20602     w                  0.000016                  0.000028
# 20603     w                  0.000013                  0.000014
# 20604     w                  0.000004                  0.000006
#
#        amplitude_around_3_Hertz  amplitude_around_4_Hertz  \
# 0                      0.000013                  0.000014
# 1                      0.000011                  0.000015
# 2                      0.000034                  0.000019
# 3                      0.000044                  0.000016
# 4                      0.000012                  0.000017
# ...                         ...                       ...
# 20600                  0.000007                  0.000003
# 20601                  0.000015                  0.000011
# 20602                  0.000031                  0.000011
# 20603                  0.000020                  0.000018
# 20604                  0.000011                  0.000025
#
#        amplitude_around_5_Hertz  amplitude_around_6_Hertz  \
# 0                      0.000023                  0.000009
# 1                      0.000022                  0.000017
# 2                      0.000013                  0.000006
# 3                      0.000007                  0.000006
# 4                      0.000020                  0.000018
# ...                         ...                       ...
# 20600                  0.000005                  0.000002
# 20601                  0.000019                  0.000006
# 20602                  0.000019                  0.000001
# 20603                  0.000007                  0.000013
# 20604                  0.000040                  0.000007
#
#        amplitude_around_7_Hertz  amplitude_around_8_Hertz  \
# 0                      0.000019                  0.000011
# 1                      0.000027                  0.000011
# 2                      0.000010                  0.000004
# 3                      0.000005                  0.000007
# 4                      0.000014                  0.000025
# ...                         ...                       ...
# 20600                  0.000005                  0.000010
# 20601                  0.000010                  0.000012
# 20602                  0.000015                  0.000002
# 20603                  0.000009                  0.000018
# 20604                  0.000005                  0.000021
#
#        amplitude_around_9_Hertz  ...  amplitude_around_92_Hertz  \
# 0                      0.000016  ...               8.364060e-09
# 1                      0.000011  ...               6.695745e-09
# 2                      0.000006  ...               1.105705e-08
# 3                      0.000006  ...               2.223992e-08
# 4                      0.000018  ...               6.541705e-09
# ...                         ...  ...                        ...
# 20600                  0.000013  ...               1.162051e-08
# 20601                  0.000009  ...               1.456810e-08
# 20602                  0.000007  ...               1.197483e-08
# 20603                  0.000005  ...               3.028127e-08
# 20604                  0.000011  ...               1.434414e-08
#
#        amplitude_around_93_Hertz  amplitude_around_94_Hertz  \
# 0                   4.208368e-09               2.177679e-09
# 1                   1.213822e-08               2.287185e-08
# 2                   3.264479e-09               1.204057e-09
# 3                   1.028462e-08               3.561479e-09
# 4                   3.312024e-09               8.779863e-09
# ...                          ...                        ...
# 20600               9.470367e-09               1.542617e-08
# 20601               9.259630e-09               3.831858e-08
# 20602               2.496412e-08               2.292325e-08
# 20603               9.760537e-09               3.475243e-09
# 20604               1.081698e-08               6.120670e-09
#
#        amplitude_around_95_Hertz  amplitude_around_96_Hertz  \
# 0                   4.342505e-09               5.130010e-09
# 1                   3.219380e-09               2.461736e-09
# 2                   5.090074e-09               5.477467e-09
# 3                   3.704753e-09               2.425319e-09
# 4                   7.400000e-09               2.890853e-09
# ...                          ...                        ...
# 20600               6.114029e-09               2.346950e-09
# 20601               3.839020e-09               4.668449e-09
# 20602               2.783310e-09               6.423075e-09
# 20603               2.667755e-09               4.243288e-09
# 20604               4.113743e-09               6.910015e-09
#
#        amplitude_around_97_Hertz  amplitude_around_98_Hertz  \
# 0                   2.852361e-09               9.772395e-10
# 1                   2.985953e-09               1.434412e-09
# 2                   1.809223e-09               7.064289e-10
# 3                   1.536834e-09               2.540238e-10
# 4                   5.709757e-10               2.171227e-09
# ...                          ...                        ...
# 20600               4.264138e-09               1.733832e-09
# 20601               1.671207e-09               2.347928e-09
# 20602               3.649511e-09               4.350072e-09
# 20603               6.048632e-09               3.234623e-09
# 20604               7.412423e-09               3.527602e-09
#
#        amplitude_around_99_Hertz  amplitude_around_100_Hertz  \
# 0                   1.876307e-09                5.457793e-09
# 1                   1.579590e-09                5.458902e-09
# 2                   1.435585e-09                7.416121e-09
# 3                   6.300358e-10                3.647454e-09
# 4                   6.757242e-10                2.005702e-09
# ...                          ...                         ...
# 20600               8.314190e-10                1.720087e-09
# 20601               2.219437e-09                2.045267e-09
# 20602               6.656486e-10                2.086456e-09
# 20603               1.421633e-09                9.709723e-10
# 20604               2.895608e-09                4.211010e-09
#
#        amplitude_around_101_Hertz
# 0                    8.653900e-08
# 1                    8.492570e-08
# 2                    1.156240e-07
# 3                    2.212800e-08
# 4                    2.861980e-10
# ...                           ...
# 20600                1.345590e-09
# 20601                6.063210e-09
# 20602                2.761580e-08
# 20603                2.062290e-08
# 20604                3.054510e-08
#
# [40863 rows x 102 columns]

# %% [markdown]
# <font color="red">**For it to work on Colab, you will need to reload your session (Exécution -> redémarrer la session)**</font>

# %% [markdown]
# <font color="orange">**Make sure to put a large amount of points otherwise the cross validation folds will be really small**</font>

# %% [markdown]
# ## Show the dataset

# %%
dataset = np.array(dataset)
dataset
# Out:
# array([['n', 9.123150377376987e-06, 1.3656147984875132e-05, ...,
#         1.8763067211047253e-09, 5.457792863483579e-09,
#         8.653900351873746e-08],
#        ['n', 9.79506089393567e-06, 9.573940179308238e-06, ...,
#         1.5795897784220971e-09, 5.4589015668904395e-09,
#         8.492570202633942e-08],
#        ['n', 1.0809589923610474e-05, 7.670862305531045e-05, ...,
#         1.435585247899773e-09, 7.4161209742684706e-09,
#         1.1562399748754617e-07],
#        ...,
#        ['w', 1.6213877302106994e-05, 2.8464069458777885e-05, ...,
#         6.656486386397154e-10, 2.08645636011473e-09,
#         2.7615799425007026e-08],
#        ['w', 1.2860698049621533e-05, 1.3600040119854384e-05, ...,
#         1.421632783715765e-09, 9.70972280009419e-10,
#         2.062290072046835e-08],
#        ['w', 3.5420524397977715e-06, 5.874647627024388e-06, ...,
#         2.8956081976616584e-09, 4.211009985155556e-09,
#         3.054509889466317e-08]], shape=(40863, 102), dtype=object)

# %%
input_data = dataset[:, 1:26].astype(float)
input_data = (input_data - input_data.mean(axis=0)) / (input_data.std(axis=0) + 1e-8)  # Standardize each feature
state_to_class = {"w": 0, "r": 1, "n": 2}
output_data = np.array([state_to_class[state] for state in dataset[:, 0]], dtype=int)

# %%
input_data
# Out:
# array([[-0.20987265, -0.08194901, -0.1050478 , ...,  1.00000539,
#          2.26371808, -0.64868881],
#        [-0.1833618 , -0.32559618, -0.23035843, ...,  0.2467585 ,
#         -0.82000237,  0.34377882],
#        [-0.14333261,  3.68134731,  1.38922012, ..., -0.79029172,
#         -0.63291958, -0.87739863],
#        ...,
#        [ 0.06989857,  0.80186398,  1.18418179, ..., -1.14156055,
#         -1.12676563, -0.92143145],
#        [-0.06240423, -0.08529781,  0.37567232, ...,  0.10524562,
#         -0.09252743,  0.62408137],
#        [-0.43008006, -0.54638901, -0.24674486, ...,  5.2523252 ,
#          0.03724136,  1.40752378]], shape=(40863, 25))

# %%
output_data
# Out:
# array([2, 2, 2, ..., 0, 0, 0], shape=(40863,))

# %%
# Check data balance
class_names = ["Awake", "REM", "Non-REM"]
unique, counts = np.unique(output_data, return_counts=True)
for label, count in zip(unique, counts):
    state = class_names[label]
    print(f"{state}: {count} samples ({count/len(output_data)*100:.1f}%)")
# Out:
# Awake: 24360 samples (59.6%)
# REM: 2839 samples (6.9%)
# Non-REM: 13664 samples (33.4%)

# %%
# %matplotlib inline

# %%
import keras
from keras import layers
from sklearn.model_selection import StratifiedKFold

pl.clf()

keras.utils.set_random_seed(123)
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=123)

class_colors = {0: "tab:blue", 1: "tab:orange", 2: "tab:green"}
validation_color = "lightgray"
class_names = ["Awake", "REM", "Non-REM"]

for i, (train_index, test_index) in enumerate(skf.split(input_data, output_data)):
  pl.figure(figsize=(4,4))

  # Plot train data
  pl.scatter(input_data[train_index][:,0], input_data[train_index][:,1], c=[class_colors[int(d)] for d in output_data[train_index]], s=100)
  pl.scatter(input_data[test_index][:,0], input_data[test_index][:,1], c=validation_color, s=100)
  pl.title(f'Split {i + 1}, validation fold in gray.')
  pl.show()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774965566.737075   29151 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1774965566.786044   29151 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774965568.099991   29151 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
def create_model():
  # 25 inputs (EEG features)
  # 1 hidden layer
  # 3 outputs: Awake, REM, Non-REM

  mlp = keras.Sequential([
      layers.Input(shape=(25,)),
      layers.Dense(32, activation="relu"),
      layers.Dense(3, activation="softmax"),
  ])

  # Experiment with hyperparameters here:
  # momentum: [0, 0.8, 0.9, 0.99]
  # learning_rate: [0.1, 0.01, 0.001, 0.0001]
  mlp.compile(
      optimizer=keras.optimizers.Adam(learning_rate=0.0005),
      loss="sparse_categorical_crossentropy",
      metrics=["accuracy"],
  )

  return mlp

mlp = create_model()
mlp.summary()
# Out:
# E0000 00:00:1774965571.580130   29151 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1774965571.595216   29151 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 931 (3.64 KB)
#  Trainable params: 931 (3.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_list = []
trained_mlp = []

for i, (train_index, test_index) in enumerate(skf.split(input_data, output_data)):
  # We need to create a new model everytime otherwise fit will continue previous training
  mlp = create_model()

  class_values = np.unique(output_data[train_index])

  history = mlp.fit(
      x=input_data[train_index],
      y=output_data[train_index],
      validation_data=(input_data[test_index], output_data[test_index]),
      epochs=100,
  )

  history_list.append(history)
  trained_mlp.append(mlp)
# Out:
# Epoch 1/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8278 - loss: 0.4752 - val_accuracy: 0.8651 - val_loss: 0.3927
# Epoch 2/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8703 - loss: 0.3625 - val_accuracy: 0.8696 - val_loss: 0.3709
# Epoch 3/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8749 - loss: 0.3470 - val_accuracy: 0.8723 - val_loss: 0.3596
# Epoch 4/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8785 - loss: 0.3378 - val_accuracy: 0.8736 - val_loss: 0.3527
# Epoch 5/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8805 - loss: 0.3316 - val_accuracy: 0.8749 - val_loss: 0.3481
# Epoch 6/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8826 - loss: 0.3269 - val_accuracy: 0.8759 - val_loss: 0.3449
# Epoch 7/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8828 - loss: 0.3235 - val_accuracy: 0.8766 - val_loss: 0.3425
# Epoch 8/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8832 - loss: 0.3207 - val_accuracy: 0.8778 - val_loss: 0.3408
# Epoch 9/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8838 - loss: 0.3185 - val_accuracy: 0.8787 - val_loss: 0.3395
# Epoch 10/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8842 - loss: 0.3167 - val_accuracy: 0.8787 - val_loss: 0.3386
# Epoch 11/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8851 - loss: 0.3152 - val_accuracy: 0.8791 - val_loss: 0.3379
# Epoch 12/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8855 - loss: 0.3140 - val_accuracy: 0.8792 - val_loss: 0.3374
# Epoch 13/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8856 - loss: 0.3129 - val_accuracy: 0.8795 - val_loss: 0.3370
# Epoch 14/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8860 - loss: 0.3120 - val_accuracy: 0.8796 - val_loss: 0.3367
# Epoch 15/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8864 - loss: 0.3111 - val_accuracy: 0.8798 - val_loss: 0.3365
# Epoch 16/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8866 - loss: 0.3103 - val_accuracy: 0.8799 - val_loss: 0.3363
# Epoch 17/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8870 - loss: 0.3096 - val_accuracy: 0.8798 - val_loss: 0.3362
# Epoch 18/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8870 - loss: 0.3090 - val_accuracy: 0.8797 - val_loss: 0.3362
# Epoch 19/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8870 - loss: 0.3084 - val_accuracy: 0.8797 - val_loss: 0.3361
# Epoch 20/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8874 - loss: 0.3078 - val_accuracy: 0.8792 - val_loss: 0.3362
# Epoch 21/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8874 - loss: 0.3073 - val_accuracy: 0.8795 - val_loss: 0.3362
# Epoch 22/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8873 - loss: 0.3068 - val_accuracy: 0.8797 - val_loss: 0.3363
# Epoch 23/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8874 - loss: 0.3064 - val_accuracy: 0.8797 - val_loss: 0.3364
# Epoch 24/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8877 - loss: 0.3059 - val_accuracy: 0.8793 - val_loss: 0.3365
# Epoch 25/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8877 - loss: 0.3055 - val_accuracy: 0.8792 - val_loss: 0.3365
# Epoch 26/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8875 - loss: 0.3051 - val_accuracy: 0.8791 - val_loss: 0.3366
# Epoch 27/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8877 - loss: 0.3047 - val_accuracy: 0.8789 - val_loss: 0.3367
# Epoch 28/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8877 - loss: 0.3044 - val_accuracy: 0.8785 - val_loss: 0.3368
# Epoch 29/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8884 - loss: 0.3041 - val_accuracy: 0.8782 - val_loss: 0.3369
# Epoch 30/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8885 - loss: 0.3038 - val_accuracy: 0.8781 - val_loss: 0.3371
# Epoch 31/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.
100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8905 - loss: 0.3034 - val_accuracy: 0.8814 - val_loss: 0.3257
# Epoch 63/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8904 - loss: 0.3033 - val_accuracy: 0.8816 - val_loss: 0.3257
# Epoch 64/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8905 - loss: 0.3033 - val_accuracy: 0.8815 - val_loss: 0.3257
# Epoch 65/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3032 - val_accuracy: 0.8815 - val_loss: 0.3257
# Epoch 66/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8908 - loss: 0.3031 - val_accuracy: 0.8815 - val_loss: 0.3257
# Epoch 67/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8904 - loss: 0.3030 - val_accuracy: 0.8815 - val_loss: 0.3257
# Epoch 68/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8903 - loss: 0.3029 - val_accuracy: 0.8817 - val_loss: 0.3257
# Epoch 69/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8905 - loss: 0.3029 - val_accuracy: 0.8816 - val_loss: 0.3258
# Epoch 70/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3028 - val_accuracy: 0.8814 - val_loss: 0.3257
# Epoch 71/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3027 - val_accuracy: 0.8812 - val_loss: 0.3258
# Epoch 72/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3026 - val_accuracy: 0.8810 - val_loss: 0.3258
# Epoch 73/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8907 - loss: 0.3026 - val_accuracy: 0.8811 - val_loss: 0.3258
# Epoch 74/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8907 - loss: 0.3025 - val_accuracy: 0.8809 - val_loss: 0.3258
# Epoch 75/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3024 - val_accuracy: 0.8806 - val_loss: 0.3259
# Epoch 76/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8907 - loss: 0.3024 - val_accuracy: 0.8808 - val_loss: 0.3259
# Epoch 77/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3023 - val_accuracy: 0.8806 - val_loss: 0.3260
# Epoch 78/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3022 - val_accuracy: 0.8803 - val_loss: 0.3260
# Epoch 79/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3022 - val_accuracy: 0.8803 - val_loss: 0.3260
# Epoch 80/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8907 - loss: 0.3021 - val_accuracy: 0.8799 - val_loss: 0.3260
# Epoch 81/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8908 - loss: 0.3020 - val_accuracy: 0.8797 - val_loss: 0.3261
# Epoch 82/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3020 - val_accuracy: 0.8796 - val_loss: 0.3261
# Epoch 83/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8907 - loss: 0.3019 - val_accuracy: 0.8795 - val_loss: 0.3261
# Epoch 84/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3018 - val_accuracy: 0.8794 - val_loss: 0.3262
# Epoch 85/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8911 - loss: 0.3017 - val_accuracy: 0.8793 - val_loss: 0.3262
# Epoch 86/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8912 - loss: 0.3017 - val_accuracy: 0.8793 - val_loss: 0.3262
# Epoch 87/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8912 - loss: 0.3016 - val_accuracy: 0.8794 - val_loss: 0.3263
# Epoch 88/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8914 - loss: 0.3016 - val_accuracy: 0.8793 - val_loss: 0.3263
# Epoch 89/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8912 - loss: 0.3015 - val_accuracy: 0.8795 - val_loss: 0.3263
# Epoch 90/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8913 - loss: 0.3015 - val_accuracy: 0.8793 - val_loss: 0.3264
# Epoch 91/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8915 - loss: 0.3014 - val_accuracy: 0.8796 - val_loss: 0.3265
# Epoch 92/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8915 - loss: 0.3014 - val_accuracy: 0.8792 - val_loss: 0.3265
# Epoch 93/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8916 - loss: 0.3013 - val_accuracy: 0.8795 - val_loss: 0.3265
# Epoch 94/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8916 - loss: 0.3013 - val_accuracy: 0.8794 - val_loss: 0.3266
# Epoch 95/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8917 - loss: 0.3012 - val_accuracy: 0.8795 - val_loss: 0.3266
# Epoch 96/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8919 - loss: 0.3011 - val_accuracy: 0.8791 - val_loss: 0.3266
# Epoch 97/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8917 - loss: 0.3011 - val_accuracy: 0.8792 - val_loss: 0.3267
# Epoch 98/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8917 - loss: 0.3010 - val_accuracy: 0.8791 - val_loss: 0.3267
# Epoch 99/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8918 - loss: 0.3010 - val_accuracy: 0.8790 - val_loss: 0.3267
# Epoch 100/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8918 - loss: 0.3009 - val_accuracy: 0.8789 - val_loss: 0.3268

# %% [markdown]
# # Plot training history

# %%
def pad_history_values(histories, key):
    max_len = max(len(history.history[key]) for history in histories)
    padded_values = np.full((len(histories), max_len), np.nan)
    for row_index, history in enumerate(histories):
        values = np.asarray(history.history[key], dtype=float)
        padded_values[row_index, :len(values)] = values
    return padded_values

train_losses = pad_history_values(history_list, 'loss')
val_losses = pad_history_values(history_list, 'val_loss')

# Calculate mean and standard deviation for training and validation losses
mean_train_loss = np.nanmean(train_losses, axis=0)
std_train_loss = np.nanstd(train_losses, axis=0)
mean_val_loss = np.nanmean(val_losses, axis=0)
std_val_loss = np.nanstd(val_losses, axis=0)

epochs = np.arange(1, len(mean_train_loss) + 1)

# Plot mean and standard deviation for training loss
pl.plot(epochs, mean_train_loss, label='Training Loss (Mean)')
pl.fill_between(epochs, mean_train_loss - std_train_loss, mean_train_loss + std_train_loss, alpha=0.3, label='Training Loss (Std)')

# Plot mean and standard deviation for validation loss
pl.plot(epochs, mean_val_loss, label='Validation Loss (Mean)')
pl.fill_between(epochs, mean_val_loss - std_val_loss, mean_val_loss + std_val_loss, alpha=0.3, label='Validation Loss (Std)')

# Add labels and legend
pl.xlabel('Epochs')
pl.ylabel('Loss')
pl.legend()

# Display the plot
pl.show()

# %% [markdown]
# # Performances

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, f1_score
import seaborn as sns

class_names = ["Awake", "REM", "Non-REM"]

def plot_confusion_matrix(confusion_matrix, title):
    # Plot confusion matrix
    pl.figure(figsize=(8, 6))
    sns.heatmap(confusion_matrix.astype(int), annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=class_names, yticklabels=class_names)
    pl.title(title)
    pl.xlabel('Predicted')
    pl.ylabel('True')
    pl.show()

f1_scores = []
mean_confusion_matrix = np.zeros((3, 3))

for i, (train_index, test_index) in enumerate(skf.split(input_data, output_data)):
    # Evaluate the trained model on the test fold
    predictions = np.argmax(trained_mlp[i].predict(input_data[test_index]), axis=1)
    true_labels = output_data[test_index]

    # Compute confusion matrix
    cm = confusion_matrix(true_labels, predictions, labels=[0, 1, 2])
    mean_confusion_matrix += cm

    # Compute confusion matrix and plot
    plot_confusion_matrix(cm, f'Confusion Matrix - Fold {i + 1}')

    # Compute F1 score
    f1 = f1_score(true_labels, predictions, average='micro')
    f1_scores.append(f1)
    print(f"F1 Score - Fold {i + 1}: {f1}")

# Plot mean confusion matrix
plot_confusion_matrix(mean_confusion_matrix, 'Global confusion matrix')

# Calculate and display the mean F1 score across all folds
mean_f1_score = np.mean(f1_scores)
print(f"Mean F1 Score across all folds: {mean_f1_score}")
# Out:
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# F1 Score - Fold 1: 0.8764407899566845
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# F1 Score - Fold 2: 0.8834887306365171
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# F1 Score - Fold 3: 0.878863519565377
# Mean F1 Score across all folds: 0.8795976800528594
