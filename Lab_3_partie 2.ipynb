# %% [markdown]
# # Practical Work 3

# %% [markdown]
# ## Loading the packages

# %%
import numpy as np
import matplotlib.pyplot as pl ## hello

# %% [markdown]
# ## The Dataset

# %%
# %pip install ipympl
# Out:
# /home/yomaru/HEIG/arn/ARN-PW3/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

 # Change this to any folder where data is if needed
mouse1 = pd.read_csv('EEG_mouse_data_1.csv')
mouse2 = pd.read_csv('EEG_mouse_data_2.csv')
dataset = pd.concat([mouse1, mouse2])
dataset
# Out:
#       state  amplitude_around_1_Hertz  amplitude_around_2_Hertz  \
# 0         n                  0.000009                  0.000014
# 1         n                  0.000010                  0.000010
# 2         n                  0.000011                  0.000077
# 3         w                  0.000003                  0.000031
# 4         w                  0.000010                  0.000011
# ...     ...                       ...                       ...
# 20600     w                  0.000025                  0.000007
# 20601     w                  0.000017                  0.000038
# 20602     w                  0.000016                  0.000028
# 20603     w                  0.000013                  0.000014
# 20604     w                  0.000004                  0.000006
#
#        amplitude_around_3_Hertz  amplitude_around_4_Hertz  \
# 0                      0.000013                  0.000014
# 1                      0.000011                  0.000015
# 2                      0.000034                  0.000019
# 3                      0.000044                  0.000016
# 4                      0.000012                  0.000017
# ...                         ...                       ...
# 20600                  0.000007                  0.000003
# 20601                  0.000015                  0.000011
# 20602                  0.000031                  0.000011
# 20603                  0.000020                  0.000018
# 20604                  0.000011                  0.000025
#
#        amplitude_around_5_Hertz  amplitude_around_6_Hertz  \
# 0                      0.000023                  0.000009
# 1                      0.000022                  0.000017
# 2                      0.000013                  0.000006
# 3                      0.000007                  0.000006
# 4                      0.000020                  0.000018
# ...                         ...                       ...
# 20600                  0.000005                  0.000002
# 20601                  0.000019                  0.000006
# 20602                  0.000019                  0.000001
# 20603                  0.000007                  0.000013
# 20604                  0.000040                  0.000007
#
#        amplitude_around_7_Hertz  amplitude_around_8_Hertz  \
# 0                      0.000019                  0.000011
# 1                      0.000027                  0.000011
# 2                      0.000010                  0.000004
# 3                      0.000005                  0.000007
# 4                      0.000014                  0.000025
# ...                         ...                       ...
# 20600                  0.000005                  0.000010
# 20601                  0.000010                  0.000012
# 20602                  0.000015                  0.000002
# 20603                  0.000009                  0.000018
# 20604                  0.000005                  0.000021
#
#        amplitude_around_9_Hertz  ...  amplitude_around_92_Hertz  \
# 0                      0.000016  ...               8.364060e-09
# 1                      0.000011  ...               6.695745e-09
# 2                      0.000006  ...               1.105705e-08
# 3                      0.000006  ...               2.223992e-08
# 4                      0.000018  ...               6.541705e-09
# ...                         ...  ...                        ...
# 20600                  0.000013  ...               1.162051e-08
# 20601                  0.000009  ...               1.456810e-08
# 20602                  0.000007  ...               1.197483e-08
# 20603                  0.000005  ...               3.028127e-08
# 20604                  0.000011  ...               1.434414e-08
#
#        amplitude_around_93_Hertz  amplitude_around_94_Hertz  \
# 0                   4.208368e-09               2.177679e-09
# 1                   1.213822e-08               2.287185e-08
# 2                   3.264479e-09               1.204057e-09
# 3                   1.028462e-08               3.561479e-09
# 4                   3.312024e-09               8.779863e-09
# ...                          ...                        ...
# 20600               9.470367e-09               1.542617e-08
# 20601               9.259630e-09               3.831858e-08
# 20602               2.496412e-08               2.292325e-08
# 20603               9.760537e-09               3.475243e-09
# 20604               1.081698e-08               6.120670e-09
#
#        amplitude_around_95_Hertz  amplitude_around_96_Hertz  \
# 0                   4.342505e-09               5.130010e-09
# 1                   3.219380e-09               2.461736e-09
# 2                   5.090074e-09               5.477467e-09
# 3                   3.704753e-09               2.425319e-09
# 4                   7.400000e-09               2.890853e-09
# ...                          ...                        ...
# 20600               6.114029e-09               2.346950e-09
# 20601               3.839020e-09               4.668449e-09
# 20602               2.783310e-09               6.423075e-09
# 20603               2.667755e-09               4.243288e-09
# 20604               4.113743e-09               6.910015e-09
#
#        amplitude_around_97_Hertz  amplitude_around_98_Hertz  \
# 0                   2.852361e-09               9.772395e-10
# 1                   2.985953e-09               1.434412e-09
# 2                   1.809223e-09               7.064289e-10
# 3                   1.536834e-09               2.540238e-10
# 4                   5.709757e-10               2.171227e-09
# ...                          ...                        ...
# 20600               4.264138e-09               1.733832e-09
# 20601               1.671207e-09               2.347928e-09
# 20602               3.649511e-09               4.350072e-09
# 20603               6.048632e-09               3.234623e-09
# 20604               7.412423e-09               3.527602e-09
#
#        amplitude_around_99_Hertz  amplitude_around_100_Hertz  \
# 0                   1.876307e-09                5.457793e-09
# 1                   1.579590e-09                5.458902e-09
# 2                   1.435585e-09                7.416121e-09
# 3                   6.300358e-10                3.647454e-09
# 4                   6.757242e-10                2.005702e-09
# ...                          ...                         ...
# 20600               8.314190e-10                1.720087e-09
# 20601               2.219437e-09                2.045267e-09
# 20602               6.656486e-10                2.086456e-09
# 20603               1.421633e-09                9.709723e-10
# 20604               2.895608e-09                4.211010e-09
#
#        amplitude_around_101_Hertz
# 0                    8.653900e-08
# 1                    8.492570e-08
# 2                    1.156240e-07
# 3                    2.212800e-08
# 4                    2.861980e-10
# ...                           ...
# 20600                1.345590e-09
# 20601                6.063210e-09
# 20602                2.761580e-08
# 20603                2.062290e-08
# 20604                3.054510e-08
#
# [40863 rows x 102 columns]

# %% [markdown]
# <font color="red">**For it to work on Colab, you will need to reload your session (Exécution -> redémarrer la session)**</font>

# %% [markdown]
# <font color="orange">**Make sure to put a large amount of points otherwise the cross validation folds will be really small**</font>

# %% [markdown]
# ## Show the dataset

# %%
dataset = np.array(dataset)
dataset
# Out:
# array([['n', 9.123150377376987e-06, 1.3656147984875132e-05, ...,
#         1.8763067211047253e-09, 5.457792863483579e-09,
#         8.653900351873746e-08],
#        ['n', 9.79506089393567e-06, 9.573940179308238e-06, ...,
#         1.5795897784220971e-09, 5.4589015668904395e-09,
#         8.492570202633942e-08],
#        ['n', 1.0809589923610474e-05, 7.670862305531045e-05, ...,
#         1.435585247899773e-09, 7.4161209742684706e-09,
#         1.1562399748754617e-07],
#        ...,
#        ['w', 1.6213877302106994e-05, 2.8464069458777885e-05, ...,
#         6.656486386397154e-10, 2.08645636011473e-09,
#         2.7615799425007026e-08],
#        ['w', 1.2860698049621533e-05, 1.3600040119854384e-05, ...,
#         1.421632783715765e-09, 9.70972280009419e-10,
#         2.062290072046835e-08],
#        ['w', 3.5420524397977715e-06, 5.874647627024388e-06, ...,
#         2.8956081976616584e-09, 4.211009985155556e-09,
#         3.054509889466317e-08]], shape=(40863, 102), dtype=object)

# %%
input_data = dataset[:, 1:26].astype(float)
input_data = (input_data - input_data.mean(axis=0)) / (input_data.std(axis=0) + 1e-8)  # Standardize each feature
state_to_class = {"w": 0, "r": 1, "n": 2}
output_data = np.array([state_to_class[state] for state in dataset[:, 0]], dtype=int)

# %%
input_data
# Out:
# array([[-0.20987265, -0.08194901, -0.1050478 , ...,  1.00000539,
#          2.26371808, -0.64868881],
#        [-0.1833618 , -0.32559618, -0.23035843, ...,  0.2467585 ,
#         -0.82000237,  0.34377882],
#        [-0.14333261,  3.68134731,  1.38922012, ..., -0.79029172,
#         -0.63291958, -0.87739863],
#        ...,
#        [ 0.06989857,  0.80186398,  1.18418179, ..., -1.14156055,
#         -1.12676563, -0.92143145],
#        [-0.06240423, -0.08529781,  0.37567232, ...,  0.10524562,
#         -0.09252743,  0.62408137],
#        [-0.43008006, -0.54638901, -0.24674486, ...,  5.2523252 ,
#          0.03724136,  1.40752378]], shape=(40863, 25))

# %%
output_data
# Out:
# array([2, 2, 2, ..., 0, 0, 0], shape=(40863,))

# %%
# Check data balance
class_names = ["Awake", "REM", "Non-REM"]
unique, counts = np.unique(output_data, return_counts=True)
for label, count in zip(unique, counts):
    state = class_names[label]
    print(f"{state}: {count} samples ({count/len(output_data)*100:.1f}%)")
# Out:
# Awake: 24360 samples (59.6%)
# REM: 2839 samples (6.9%)
# Non-REM: 13664 samples (33.4%)

# %%
# %matplotlib inline

# %%
import keras
from keras import layers
from sklearn.model_selection import StratifiedKFold

pl.clf()

keras.utils.set_random_seed(123)
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=123)

class_colors = {0: "tab:blue", 1: "tab:orange", 2: "tab:green"}
validation_color = "lightgray"
class_names = ["Awake", "REM", "Non-REM"]

for i, (train_index, test_index) in enumerate(skf.split(input_data, output_data)):
  pl.figure(figsize=(4,4))

  # Plot train data
  pl.scatter(input_data[train_index][:,0], input_data[train_index][:,1], c=[class_colors[int(d)] for d in output_data[train_index]], s=100)
  pl.scatter(input_data[test_index][:,0], input_data[test_index][:,1], c=validation_color, s=100)
  pl.title(f'Split {i + 1}, validation fold in gray.')
  pl.show()

# %%
def create_model():
  # 25 inputs (EEG features)
  # 1 hidden layer
  # 3 outputs: Awake, REM, Non-REM

  mlp = keras.Sequential([
      layers.Input(shape=(25,)),
      layers.Dense(32, activation="relu"),
      layers.Dense(3, activation="softmax"),
  ])

  # Experiment with hyperparameters here:
  # momentum: [0, 0.8, 0.9, 0.99]
  # learning_rate: [0.1, 0.01, 0.001, 0.0001]
  mlp.compile(
      optimizer=keras.optimizers.Adam(learning_rate=0.0005),
      loss="sparse_categorical_crossentropy",
      metrics=["accuracy"],
  )

  return mlp

mlp = create_model()
mlp.summary()
# Out:
# Model: "sequential_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_60 (Dense)                │ (None, 32)             │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_61 (Dense)                │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 931 (3.64 KB)
#  Trainable params: 931 (3.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_list = []
trained_mlp = []

from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=15,
    min_delta=1e-4,
    restore_best_weights=True,
)
reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    min_delta=1e-4,
    min_lr=1e-5,
    verbose=1,
)

for i, (train_index, test_index) in enumerate(skf.split(input_data, output_data)):
  # We need to create a new model everytime otherwise fit will continue previous training
  mlp = create_model()

  class_values = np.unique(output_data[train_index])
  class_weights = compute_class_weight(class_weight="balanced", classes=class_values, y=output_data[train_index])
  class_weights = np.sqrt(class_weights)
  class_weights = class_weights / np.mean(class_weights)
  class_weight_dict = dict(zip(class_values, class_weights))

  history = mlp.fit(
      x=input_data[train_index],
      y=output_data[train_index],
      validation_data=(input_data[test_index], output_data[test_index]),
      epochs=300,
      batch_size=128,
      class_weight=class_weight_dict,
      callbacks=[early_stopping, reduce_lr],
  )

  history_list.append(history)
  trained_mlp.append(mlp)
# Out:
# Epoch 1/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7408 - loss: 0.5208 - val_accuracy: 0.8423 - val_loss: 0.4962 - learning_rate: 5.0000e-04
# Epoch 2/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8565 - loss: 0.3649 - val_accuracy: 0.8520 - val_loss: 0.4398 - learning_rate: 5.0000e-04
# Epoch 3/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8600 - loss: 0.3358 - val_accuracy: 0.8549 - val_loss: 0.4202 - learning_rate: 5.0000e-04
# Epoch 4/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8623 - loss: 0.3237 - val_accuracy: 0.8567 - val_loss: 0.4100 - learning_rate: 5.0000e-04
# Epoch 5/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8633 - loss: 0.3167 - val_accuracy: 0.8579 - val_loss: 0.4032 - learning_rate: 5.0000e-04
# Epoch 6/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8646 - loss: 0.3118 - val_accuracy: 0.8592 - val_loss: 0.3978 - learning_rate: 5.0000e-04
# Epoch 7/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8662 - loss: 0.3080 - val_accuracy: 0.8598 - val_loss: 0.3935 - learning_rate: 5.0000e-04
# Epoch 8/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8673 - loss: 0.3048 - val_accuracy: 0.8604 - val_loss: 0.3898 - learning_rate: 5.0000e-04
# Epoch 9/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8684 - loss: 0.3022 - val_accuracy: 0.8611 - val_loss: 0.3867 - learning_rate: 5.0000e-04
# Epoch 10/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8690 - loss: 0.2999 - val_accuracy: 0.8626 - val_loss: 0.3839 - learning_rate: 5.0000e-04
# Epoch 11/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8695 - loss: 0.2978 - val_accuracy: 0.8636 - val_loss: 0.3816 - learning_rate: 5.0000e-04
# Epoch 12/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8701 - loss: 0.2960 - val_accuracy: 0.8649 - val_loss: 0.3795 - learning_rate: 5.0000e-04
# Epoch 13/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8709 - loss: 0.2943 - val_accuracy: 0.8654 - val_loss: 0.3777 - learning_rate: 5.0000e-04
# Epoch 14/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8712 - loss: 0.2928 - val_accuracy: 0.8662 - val_loss: 0.3760 - learning_rate: 5.0000e-04
# Epoch 15/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8721 - loss: 0.2914 - val_accuracy: 0.8663 - val_loss: 0.3745 - learning_rate: 5.0000e-04
# Epoch 16/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8731 - loss: 0.2901 - val_accuracy: 0.8669 - val_loss: 0.3733 - learning_rate: 5.0000e-04
# Epoch 17/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8734 - loss: 0.2889 - val_accuracy: 0.8672 - val_loss: 0.3720 - learning_rate: 5.0000e-04
# Epoch 18/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8738 - loss: 0.2877 - val_accuracy: 0.8672 - val_loss: 0.3710 - learning_rate: 5.0000e-04
# Epoch 19/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8745 - loss: 0.2867 - val_accuracy: 0.8673 - val_loss: 0.3700 - learning_rate: 5.0000e-04
# Epoch 20/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8750 - loss: 0.2858 - val_accuracy: 0.8679 - val_loss: 0.3692 - learning_rate: 5.0000e-04
# Epoch 21/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8759 - loss: 0.2849 - val_accuracy: 0.8680 - val_loss: 0.3685 - learning_rate: 5.0000e-04
# Epoch 22/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8761 - loss: 0.2841 - val_accuracy: 0.8681 - val_loss: 0.3678 - learning_rate: 5.0000e-04
# Epoch 23/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8760 - loss: 0.2834 - val_accuracy: 0.8683 - val_loss: 0.3672 - learning_rate: 5.0000e-04
# Epoch 24/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8766 - loss: 0.2828 - val_accuracy: 0.8687 - val_loss: 0.3667 - learning_rate: 5.0000e-04
# Epoch 25/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8762 - loss: 0.2821 - val_accuracy: 0.8687 - val_loss: 0.3664 - learning_rate: 5.0000e-04
# Epoch 26/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8763 - loss: 0.2816 - val_accuracy: 0.8688 - val_loss: 0.3660 - learning_rate: 5.0000e-04
# Epoch 27/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8763 - loss: 0.2811 - val_accuracy: 0.8692 - val_loss: 0.3657 - learning_rate: 5.0000e-04
# Epoch 28/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8766 - loss: 0.2806 - val_accuracy: 0.8693 - val_loss: 0.3654 - learning_rate: 5.0000e-04
# Epoch 29/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8767 - loss: 0.2801 - val_accuracy: 0.8693 - val_loss: 0.3651 - learning_rate: 5.0000e-04
# Epoch 30/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8769 - loss: 0.2796 - val_accuracy: 0.8689 - val_loss: 0.3649 - learning_rate: 5.0000e-04
# Epoch 31/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8773 - loss: 0.2792 - val_accuracy: 0.8687 - val_loss: 0.3647 - learning_rate: 5.0000e-04
# Epoch 32/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8775 - loss: 0.2787 - val_accuracy: 0.8690 - val_loss: 0.3645 - learning_rate: 5.0000e-04
# Epoch 33/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8775 - loss: 0.2783 - val_accuracy: 0.8689 - val_loss: 0.3644 - learning_rate: 5.0000e-04
# Epoch 34/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8777 - loss: 0.2779 - val_accuracy: 0.8692 - val_loss: 0.3643 - learning_rate: 5.0000e-04
# Epoch 35/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8781 - loss: 0.2776 - val_accuracy: 0.8697 - val_loss: 0.3640 - learning_rate: 5.0000e-04
# Epoch 36/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8781 - loss: 0.2772 - val_accuracy: 0.8697 - val_loss: 0.3640 - learning_rate: 5.0000e-04
# Epoch 37/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8786 - loss: 0.2769 - val_accuracy: 0.8700 - val_loss: 0.3639 - learning_rate: 5.0000e-04
# Epoch 38/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8791 - loss: 0.2765 - val_accuracy: 0.8700 - val_loss: 0.3637 - learning_rate: 5.0000e-04
# Epoch 39/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8791 - loss: 0.2762 - val_accuracy: 0.8699 - val_loss: 0.3637 - learning_rate: 5.0000e-04
# Epoch 40/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8795 - loss: 0.2759 - val_accuracy: 0.8697 - val_loss: 0.3637 - learning_rate: 5.0000e-04
# Epoch 41/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8794 - loss: 0.2757 - val_accuracy: 0.8698 - val_loss: 0.3635 - learning_rate: 5.0000e-04
# Epoch 42/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8796 - loss: 0.2754 - val_accuracy: 0.8700 - val_loss: 0.3635 - learning_rate: 5.0000e-04
# Epoch 43/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8799 - loss: 0.2751 - val_accuracy: 0.8697 - val_loss: 0.3634 - learning_rate: 5.0000e-04
# Epoch 44/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8797 - loss: 0.2749 - val_accuracy: 0.8696 - val_loss: 0.3634 - learning_rate: 5.0000e-04
# Epoch 45/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8797 - loss: 0.2746 - val_accuracy: 0.8697 - val_loss: 0.3633 - learning_rate: 5.0000e-04
# Epoch 46/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8796 - loss: 0.2744 - val_accuracy: 0.8701 - val_loss: 0.3633 - learning_rate: 5.0000e-04
# Epoch 47/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8795 - loss: 0.2742 - val_accuracy: 0.8699 - val_loss: 0.3633 - learning_rate: 5.0000e-04
# Epoch 48/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8795 - loss: 0.2739 - val_accuracy: 0.8698 - val_loss: 0.3633 - learning_rate: 5.0000e-04
# Epoch 49/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8795 - loss: 0.2737 - val_accuracy: 0.8694 - val_loss: 0.3633 - learning_rate: 5.0000e-04
# Epoch 50/300
# 196/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8793 - loss: 0.2761
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8796 - loss: 0.2735 - val_accuracy: 0.8695 - val_loss: 0.3633 - learning_rate: 5.0000e-04
# Epoch 51/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8801 - loss: 0.2726 - val_accuracy: 0.8698 - val_loss: 0.3623 - learning_rate: 2.5000e-04
# Epoch 52/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8805 - loss: 0.2725 - val_accuracy: 0.8698 - val_loss: 0.3622 - learning_rate: 2.5000e-04
# Epoch 53/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8806 - loss: 0.2724 - val_accuracy: 0.8695 - val_loss: 0.3622 - learning_rate: 2.5000e-04
# Epoch 54/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8808 - loss: 0.2723 - val_accuracy: 0.8694 - val_loss: 0.3622 - learning_rate: 2.5000e-04
# Epoch 55/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8808 - loss: 0.2722 - val_accuracy: 0.8695 - val_loss: 0.3622 - learning_rate: 2.5000e-04
# Epoch 56/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8808 - loss: 0.2721 - val_accuracy: 0.8693 - val_loss: 0.3622 - learning_rate: 2.5000e-04
# Epoch 57/300
# 190/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8804 - loss: 0.2750
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8809 - loss: 0.2720 - val_accuracy: 0.8690 - val_loss: 0.3622 - learning_rate: 2.5000e-04
# Epoch 58/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2715 - val_accuracy: 0.8695 - val_loss: 0.3618 - learning_rate: 1.2500e-04
# Epoch 59/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2715 - val_accuracy: 0.8695 - val_loss: 0.3618 - learning_rate: 1.2500e-04
# Epoch 60/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8812 - loss: 0.2714 - val_accuracy: 0.8693 - val_loss: 0.3617 - learning_rate: 1.2500e-04
# Epoch 61/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8812 - loss: 0.2714 - val_accuracy: 0.8695 - val_loss: 0.3617 - learning_rate: 1.2500e-04
# Epoch 62/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2713 - val_accuracy: 0.8694 - val_loss: 0.3617 - learning_rate: 1.2500e-04
# Epoch 63/300
# 190/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8808 - loss: 0.2744
# Epoch 63: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8811 - loss: 0.2713 - val_accuracy: 0.8693 - val_loss: 0.3617 - learning_rate: 1.2500e-04
# Epoch 64/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2710 - val_accuracy: 0.8695 - val_loss: 0.3615 - learning_rate: 6.2500e-05
# Epoch 65/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8809 - loss: 0.2710 - val_accuracy: 0.8695 - val_loss: 0.3614 - learning_rate: 6.2500e-05
# Epoch 66/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2710 - val_accuracy: 0.8694 - val_loss: 0.3614 - learning_rate: 6.2500e-05
# Epoch 67/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8809 - loss: 0.2710 - val_accuracy: 0.8694 - val_loss: 0.3614 - learning_rate: 6.2500e-05
# Epoch 68/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2709 - val_accuracy: 0.8694 - val_loss: 0.3614 - learning_rate: 6.2500e-05
# Epoch 69/300
# 198/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8803 - loss: 0.2740
# Epoch 69: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8809 - loss: 0.2709 - val_accuracy: 0.8694 - val_loss: 0.3614 - learning_rate: 6.2500e-05
# Epoch 70/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8809 - loss: 0.2708 - val_accuracy: 0.8693 - val_loss: 0.3613 - learning_rate: 3.1250e-05
# Epoch 71/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2708 - val_accuracy: 0.8694 - val_loss: 0.3613 - learning_rate: 3.1250e-05
# Epoch 72/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2708 - val_accuracy: 0.8694 - val_loss: 0.3613 - learning_rate: 3.1250e-05
# Epoch 73/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8810 - loss: 0.2708 - val_accuracy: 0.8695 - val_loss: 0.3613 - learning_rate: 3.1250e-05
# Epoch 74/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2708 - val_accuracy: 0.8695 - val_loss: 0.3613 - learning_rate: 3.1250e-05
# Epoch 75/300
# 197/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8804 - loss: 0.2739
# Epoch 75: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2707 - val_accuracy: 0.8695 - val_loss: 0.3613 - learning_rate: 3.1250e-05
# Epoch 76/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2707 - val_accuracy: 0.8695 - val_loss: 0.3612 - learning_rate: 1.5625e-05
# Epoch 77/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2707 - val_accuracy: 0.8695 - val_loss: 0.3612 - learning_rate: 1.5625e-05
# Epoch 78/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2707 - val_accuracy: 0.8695 - val_loss: 0.3612 - learning_rate: 1.5625e-05
# Epoch 79/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2707 - val_accuracy: 0.8695 - val_loss: 0.3612 - learning_rate: 1.5625e-05
# Epoch 80/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2707 - val_accuracy: 0.8695 - val_loss: 0.3612 - learning_rate: 1.5625e-05
# Epoch 81/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2707 - val_accuracy: 0.8695 - val_loss: 0.3612 - learning_rate: 1.5625e-05
# Epoch 82/300
# 196/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8804 - loss: 0.2738
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1e-05.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2706 - val_accuracy: 0.8695 - val_loss: 0.3612 - learning_rate: 1.5625e-05
# Epoch 83/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8811 - loss: 0.2706 - val_accuracy: 0.8695 - val_loss: 0.3612 - learning_rate: 1.0000e-05
# Epoch 84/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2706 - val_accuracy: 0.8695 - val_loss: 0.3612 - learning_rate: 1.0000e-05
# Epoch 85/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2706 - val_accuracy: 0.8695 - val_loss: 0.3612 - learning_rate: 1.0000e-05
# Epoch 86/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2706 - val_accuracy: 0.8695 - val_loss: 0.3612 - learning_rate: 1.0000e-05
# Epoch 87/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2706 - val_accuracy: 0.8694 - val_loss: 0.3612 - learning_rate: 1.0000e-05
# Epoch 88/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2706 - val_accuracy: 0.8694 - val_loss: 0.3612 - learning_rate: 1.0000e-05
# Epoch 89/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2706 - val_accuracy: 0.8694 - val_loss: 0.3612 - learning_rate: 1.0000e-05
# Epoch 90/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2706 - val_accuracy: 0.8694 - val_loss: 0.3612 - learning_rate: 1.0000e-05
# Epoch 91/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8811 - loss: 0.2706 - val_accuracy: 0.8694 - val_loss: 0.3612 - learning_rate: 1.0000e-05
# Epoch 92/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.2706 - val_accuracy: 0.8694 - val_loss: 0.3612 - learning_rate: 1.0000e-05
# Epoch 1/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7092 - loss: 0.5457 - val_accuracy: 0.8482 - val_loss: 0.5086 - learning_rate: 5.0000e-04
# Epoch 2/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8554 - loss: 0.3834 - val_accuracy: 0.8587 - val_loss: 0.4355 - learning_rate: 5.0000e-04
# Epoch 3/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8623 - loss: 0.3432 - val_accuracy: 0.8609 - val_loss: 0.4104 - learning_rate: 5.0000e-04
# Epoch 4/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8621 - loss: 0.3269 - val_accuracy: 0.8603 - val_loss: 0.3998 - learning_rate: 5.0000e-04
# Epoch 5/300
# 194/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8602 - loss: 0.3231
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8619 - loss: 0.3188 - val_accuracy: 0.8610 - val_loss: 0.3936 - learning_rate: 5.0000e-04
# Epoch 6/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8625 - loss: 0.3141 - val_accuracy: 0.8633 - val_loss: 0.3884 - learning_rate: 2.5000e-04
# Epoch 7/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8635 - loss: 0.3118 - val_accuracy: 0.8633 - val_loss: 0.3863 - learning_rate: 2.5000e-04
# Epoch 8/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8642 - loss: 0.3097 - val_accuracy: 0.8643 - val_loss: 0.3845 - learning_rate: 2.5000e-04
# Epoch 9/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8641 - loss: 0.3079 - val_accuracy: 0.8649 - val_loss: 0.3828 - learning_rate: 2.5000e-04
# Epoch 10/300
# 194/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8633 - loss: 0.3091
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8648 - loss: 0.3062 - val_accuracy: 0.8651 - val_loss: 0.3812 - learning_rate: 2.5000e-04
# Epoch 11/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8649 - loss: 0.3047 - val_accuracy: 0.8659 - val_loss: 0.3792 - learning_rate: 1.2500e-04
# Epoch 12/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8652 - loss: 0.3040 - val_accuracy: 0.8662 - val_loss: 0.3782 - learning_rate: 1.2500e-04
# Epoch 13/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8656 - loss: 0.3032 - val_accuracy: 0.8663 - val_loss: 0.3775 - learning_rate: 1.2500e-04
# Epoch 14/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8658 - loss: 0.3026 - val_accuracy: 0.8663 - val_loss: 0.3769 - learning_rate: 1.2500e-04
# Epoch 15/300
# 196/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8653 - loss: 0.3041
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8664 - loss: 0.3019 - val_accuracy: 0.8666 - val_loss: 0.3763 - learning_rate: 1.2500e-04
# Epoch 1/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7169 - loss: 0.5827 - val_accuracy: 0.8383 - val_loss: 0.5099 - learning_rate: 5.0000e-04
# Epoch 2/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8481 - loss: 0.3854 - val_accuracy: 0.8535 - val_loss: 0.4295 - learning_rate: 5.0000e-04
# Epoch 3/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8570 - loss: 0.3472 - val_accuracy: 0.8582 - val_loss: 0.4038 - learning_rate: 5.0000e-04
# Epoch 4/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8600 - loss: 0.3317 - val_accuracy: 0.8610 - val_loss: 0.3921 - learning_rate: 5.0000e-04
# Epoch 5/300
# 198/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8617 - loss: 0.3242
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8622 - loss: 0.3230 - val_accuracy: 0.8619 - val_loss: 0.3848 - learning_rate: 5.0000e-04
# Epoch 6/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8641 - loss: 0.3178 - val_accuracy: 0.8632 - val_loss: 0.3813 - learning_rate: 2.5000e-04
# Epoch 7/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8647 - loss: 0.3152 - val_accuracy: 0.8637 - val_loss: 0.3788 - learning_rate: 2.5000e-04
# Epoch 8/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8652 - loss: 0.3129 - val_accuracy: 0.8641 - val_loss: 0.3765 - learning_rate: 2.5000e-04
# Epoch 9/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8655 - loss: 0.3109 - val_accuracy: 0.8648 - val_loss: 0.3745 - learning_rate: 2.5000e-04
# Epoch 10/300
# 195/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8653 - loss: 0.3101
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8662 - loss: 0.3090 - val_accuracy: 0.8657 - val_loss: 0.3726 - learning_rate: 2.5000e-04
# Epoch 11/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8667 - loss: 0.3074 - val_accuracy: 0.8667 - val_loss: 0.3712 - learning_rate: 1.2500e-04
# Epoch 12/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8671 - loss: 0.3065 - val_accuracy: 0.8675 - val_loss: 0.3702 - learning_rate: 1.2500e-04
# Epoch 13/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8670 - loss: 0.3057 - val_accuracy: 0.8671 - val_loss: 0.3694 - learning_rate: 1.2500e-04
# Epoch 14/300
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8672 - loss: 0.3049 - val_accuracy: 0.8669 - val_loss: 0.3686 - learning_rate: 1.2500e-04
# Epoch 15/300
# 192/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8670 - loss: 0.3057
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8676 - loss: 0.3042 - val_accuracy: 0.8667 - val_loss: 0.3679 - learning_rate: 1.2500e-04

# %% [markdown]
# # Plot training history

# %%
def pad_history_values(histories, key):
    max_len = max(len(history.history[key]) for history in histories)
    padded_values = np.full((len(histories), max_len), np.nan)
    for row_index, history in enumerate(histories):
        values = np.asarray(history.history[key], dtype=float)
        padded_values[row_index, :len(values)] = values
    return padded_values

train_losses = pad_history_values(history_list, 'loss')
val_losses = pad_history_values(history_list, 'val_loss')

# Calculate mean and standard deviation for training and validation losses
mean_train_loss = np.nanmean(train_losses, axis=0)
std_train_loss = np.nanstd(train_losses, axis=0)
mean_val_loss = np.nanmean(val_losses, axis=0)
std_val_loss = np.nanstd(val_losses, axis=0)

epochs = np.arange(1, len(mean_train_loss) + 1)

# Plot mean and standard deviation for training loss
pl.plot(epochs, mean_train_loss, label='Training Loss (Mean)')
pl.fill_between(epochs, mean_train_loss - std_train_loss, mean_train_loss + std_train_loss, alpha=0.3, label='Training Loss (Std)')

# Plot mean and standard deviation for validation loss
pl.plot(epochs, mean_val_loss, label='Validation Loss (Mean)')
pl.fill_between(epochs, mean_val_loss - std_val_loss, mean_val_loss + std_val_loss, alpha=0.3, label='Validation Loss (Std)')

# Add labels and legend
pl.xlabel('Epochs')
pl.ylabel('Loss')
pl.legend()

# Display the plot
pl.show()

# %% [markdown]
# # Performances

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, f1_score
import seaborn as sns

class_names = ["Awake", "REM", "Non-REM"]

def plot_confusion_matrix(confusion_matrix, title):
    # Plot confusion matrix
    pl.figure(figsize=(8, 6))
    sns.heatmap(confusion_matrix.astype(int), annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=class_names, yticklabels=class_names)
    pl.title(title)
    pl.xlabel('Predicted')
    pl.ylabel('True')
    pl.show()

f1_scores = []
mean_confusion_matrix = np.zeros((3, 3))

for i, (train_index, test_index) in enumerate(skf.split(input_data, output_data)):
    # Evaluate the trained model on the test fold
    predictions = np.argmax(trained_mlp[i].predict(input_data[test_index]), axis=1)
    true_labels = output_data[test_index]

    # Compute confusion matrix
    cm = confusion_matrix(true_labels, predictions, labels=[0, 1, 2])
    mean_confusion_matrix += cm

    # Compute confusion matrix and plot
    plot_confusion_matrix(cm, f'Confusion Matrix - Fold {i + 1}')

    # Compute F1 score
    f1 = f1_score(true_labels, predictions, average='micro')
    f1_scores.append(f1)
    print(f"F1 Score - Fold {i + 1}: {f1}")

# Plot mean confusion matrix
plot_confusion_matrix(mean_confusion_matrix, 'Global confusion matrix')

# Calculate and display the mean F1 score across all folds
mean_f1_score = np.mean(f1_scores)
print(f"Mean F1 Score across all folds: {mean_f1_score}")
# Out:
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step
# F1 Score - Fold 1: 0.7796983094108526
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# F1 Score - Fold 2: 0.6702674723490868
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step
# F1 Score - Fold 3: 0.6914640152999313
# Mean F1 Score across all folds: 0.7138099323532902

# %% [markdown]
# # Exercise
#
# Please try changing hyperparameters (number of neurons, number of layers, learning rate, momentum, number of epochs...) and observe the impact it has on training and validation loss, convergence, and computation time. For instance, observe if there's overfitting if you put a high number (i.e. 128) of neurons in the hidden layer.
#
# You can also experiment with different datasets (clear separation between classes, unbalanced...)
